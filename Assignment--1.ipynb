# %% [markdown]
# 1.	Develop a code for below scenario

# %%
#1
year=int(input("enter a year"))
y=year%12
if y==1:
    print("rooster")
elif y==2:
    print("dog")
elif y==3:
    print("pig")
elif y==4:
    print("rat")
elif y==5:
    print("ox")
elif y==6:
    print("tiger")
elif y==7:
    print("rabbit")
elif y==8:
    print("dragon")
elif y==9:
    print("snake")
elif y==10:
    print("horse")
elif y==11:
    print("sheep")
elif y==0:
    print("monkey")
# Out:
# enter a year2000
# dragon

# %% [markdown]
# 2.	A Quick Fox Transport Co. wants to develop an application for calculating amount based on distance and weight of goods. The charges (Amount) to be calculated as per rates given below.
#
# Input:  Distance to be travel: 520
# Weight of the goods: 50
# Output: Amount to be charged: 3120 /-

# %%
#2 
dist=int(input("enter the distance")) 
wt=int(input("enter weight")) 
if dist>=500: 
    if wt<10: 
        res=dist*5
    elif wt<100: 
        res=dist*6 
    else: 
        res=dist*7
else: 
    if wt<100: 
        res=dist*5
    else: 
        res=dist*8

print("amount to be charged is {}".format(res))
# Out:
# enter the distance20
# enter weight20
# amount to be charged is 100

# %% [markdown]
# 3.	The Entertainment Paradise
#
#  A theater in Delhi wants to develop a computerized Booking System. The theater offers different types of seats. The Ticket rates are- Stalls- Rs. 625/-, Circle- Rs.750/-, Upper Class- Rs.850/- and Box- Rs.1000/-. A discount is given 10% of total amount if tickets are purchased on Cash. In case of credit card holders 5% discount is given.
# Input: 	Type of Seat: Circle
# Payment mode: cash
# Output: Cost of ticket: 675

# %%
#3
seat=input("enter type of seat")
pm=input("enter payment mode cash or credit card")
amt=int()
if seat == "stalls":
    amt=625
elif seat == "circle":
    amt=750
elif seat == "upper class":
    amt=850
elif seat == "box":
    amt=1000
if pm == "cash":
    d=amt*(10/100)
    amt=amt-d
elif pm == "credit card":
    d=amt*5/100
    amt=amt-d
    
print("amount to be paid is:",amt)
# Out:
# enter type of seatcircle
# enter payment mode cash or credit cardcash
# amount to be paid is: 675.0

# %% [markdown]
# 4.	Develop a program that calculates the energy needed to heat water from an initial temperature to a final temperature. Your program should prompt the user to enter the amount of water in kilograms and the initial and final temperatures of the water. The formula to compute the energy is
# Q = M * (finalTemperature – initialTemperature) * 4184.
# where M is the weight of water in kilograms, temperatures are in degrees Celsius,  and energy Q is measured in joules. (L6)

# %%
#4
print("enter:")
ini=int(input("initial temperature"))
fin=int(input("final temperature"))
wt=int(input("amount of water in kilograms"))
q=wt*(fin-ini)*4184
print("energy required is :",q,"J")
# Out:
# enter:
# initial temperature30
# final temperature40
# amount of water in kilograms20
# energy required is : 836800 J

# %% [markdown]
# 5.	Develop a program that prompts user to enter month and  print
# a.	“Winter ” -   December ,January and February
# b.	“Spring”  -   March ,April and May
# c.	“Summer”  --- June ,July, August
# d.	“Autumn ”  -- September ,October, November

# %%
#5
print("which season is this???") 
mon=input("enter a month")
if mon in ["january","february","december"]:
    print("IT'S WINTER SEASON")
elif mon in ["march","april","may"]:
    print("IT'S SPRING SEASON")
elif mon in ["june,july,august"]:
    print("IT'S SUMMER SEASON")
else:
    print("IT'S AUTUMN SEASAON")
# Out:
# which season is this???
# enter a monthmarch
# IT'S SPRING SEASON

# %% [markdown]
# 6.	Body Mass Index

# %%
#6
weight=int(input("enter weight in pounds"))
height=float(input("enter height in inches"))
weight=weight*0.45359237
height=height*0.0254
bmi=weight/height**2
print(bmi)
# Out:
# enter weight in pounds30
# enter height in inches5
# 843.6834955669912

# %% [markdown]
# 7.	Write a program that reads an integer between 100 and 1000 and adds all the digits in the integer 	(	ex: input 745 	# output =16	(7+4+5)	)

# %%
#7
import math 
n=int(input("enter a no. b/w 100 and 1000 \n"))
s=0
while(n!=0):
    r=n%10
    s=math.floor(s+r)
    n=n/10
print(s)
# Out:
# enter a no. b/w 100 and 1000
# 256
# 13

# %% [markdown]
# 8.	Print all palindrome numbers between 1 to 1000.

# %%
#8

c=0 
s=0
p=0
for i in range(1,1000,1):
    n=i
    t=n
    s=0
    while(n!=0):
        r=n%10
        #print(r)
        s=r+(s*10)
        n=n//10
    print("t=",t,"s=",s)
    if(t==s):
        print(s,"is a palindrome")
    else:
        print("not a palindrome")
# Out:
# t= 1 s= 1
# 1 is a palindrome
# t= 2 s= 2
# 2 is a palindrome
# t= 3 s= 3
# 3 is a palindrome
# t= 4 s= 4
# 4 is a palindrome
# t= 5 s= 5
# 5 is a palindrome
# t= 6 s= 6
# 6 is a palindrome
# t= 7 s= 7
# 7 is a palindrome
# t= 8 s= 8
# 8 is a palindrome
# t= 9 s= 9
# 9 is a palindrome
# t= 10 s= 1
# not a palindrome
# t= 11 s= 11
# 11 is a palindrome
# t= 12 s= 21
# not a palindrome
# t= 13 s= 31
# not a palindrome
# t= 14 s= 41
# not a palindrome
# t= 15 s= 51
# not a palindrome
# t= 16 s= 61
# not a palindrome
# t= 17 s= 71
# not a palindrome
# t= 18 s= 81
# not a palindrome
# t= 19 s= 91
# not a palindrome
# t= 20 s= 2
# not a palindrome
# t= 21 s= 12
# not a palindrome
# t= 22 s= 22
# 22 is a palindrome
# t= 23 s= 32
# not a palindrome
# t= 24 s= 42
# not a palindrome
# t= 25 s= 52
# not a palindrome
# t= 26 s= 62
# not a palindrome
# t= 27 s= 72
# not a palindrome
# t= 28 s= 82
# not a palindrome
# t= 29 s= 92
# not a palindrome
# t= 30 s= 3
# not a palindrome
# t= 31 s= 13
# not a palindrome
# t= 32 s= 23
# not a palindrome
# t= 33 s= 33
# 33 is a palindrome
# t= 34 s= 43
# not a palindrome
# t= 35 s= 53
# not a palindrome
# t= 36 s= 63
# not a palindrome
# t= 37 s= 73
# not a palindrome
# t= 38 s= 83
# not a palindrome
# t= 39 s= 93
# not a palindrome
# t= 40 s= 4
# not a palindrome
# t= 41 s= 14
# not a palindrome
# t= 42 s= 24
# not a palindrome
# t= 43 s= 34
# not a palindrome
# t= 44 s= 44
# 44 is a palindrome
# t= 45 s= 54
# not a palindrome
# t= 46 s= 64
# not a palindrome
# t= 47 s= 74
# not a palindrome
# t= 48 s= 84
# not a palindrome
# t= 49 s= 94
# not a palindrome
# t= 50 s= 5
# not a palindrome
# t= 51 s= 15
# not a palindrome
# t= 52 s= 25
# not a palindrome
# t= 53 s= 35
# not a palindrome
# t= 54 s= 45
# not a palindrome
# t= 55 s= 55
# 55 is a palindrome
# t= 56 s= 65
# not a palindrome
# t= 57 s= 75
# not a palindrome
# t= 58 s= 85
# not a palindrome
# t= 59 s= 95
# not a palindrome
# t= 60 s= 6
# not a palindrome
# t= 61 s= 16
# not a palindrome
# t= 62 s= 26
# not a palindrome
# t= 63 s= 36
# not a palindrome
# t= 64 s= 46
# not a palindrome
# t= 65 s= 56
# not a palindrome
# t= 66 s= 66
# 66 is a palindrome
# t= 67 s= 76
# not a palindrome
# t= 68 s= 86
# not a palindrome
# t= 69 s= 96
# not a palindrome
# t= 70 s= 7
# not a palindrome
# t= 71 s= 17
# not a palindrome
# t= 72 s= 27
# not a palindrome
# t= 73 s= 37
# not a palindrome
# t= 74 s= 47
# not a palindrome
# t= 75 s= 57
# not a palindrome
# t= 76 s= 67
# not a palindrome
# t= 77 s= 77
# 77 is a palindrome
# t= 78 s= 87
# not a palindrome
# t= 79 s= 97
# not a palindrome
# t= 80 s= 8
# not a palindrome
# t= 81 s= 18
# not a palindrome
# t= 82 s= 28
# not a palindrome
# t= 83 s= 38
# not a palindrome
# t= 84 s= 48
# not a palindrome
# t= 85 s= 58
# not a palindrome
# t= 86 s= 68
# not a palindrome
# t= 87 s= 78
# not a palindrome
# t= 88 s= 88
# 88 is a palindrome
# t= 89 s= 98
# not a palindrome
# t= 90 s= 9
# not a palindrome
# t= 91 s= 19
# not a palindrome
# t= 92 s= 29
# not a palindrome
# t= 93 s= 39
# not a palindrome
# t= 94 s= 49
# not a palindrome
# t= 95 s= 59
# not a palindrome
# t= 96 s= 69
# not a palindrome
# t= 97 s= 79
# not a palindrome
# t= 98 s= 89
# not a palindrome
# t= 99 s= 99
# 99 is a palindrome
# t= 100 s= 1
# not a palindrome
# t= 101 s= 101
# 101 is a palindrome
# t= 102 s= 201
# not a palindrome
# t= 103 s= 301
# not a palindrome
# t= 104 s= 401
# not a palindrome
# t= 105 s= 501
# not a palindrome
# t= 106 s= 601
# not a palindrome
# t= 107 s= 701
# not a palindrome
# t= 108 s= 801
# not a palindrome
# t= 109 s= 901
# not a palindrome
# t= 110 s= 11
# not a palindrome
# t= 111 s= 111
# 111 is a palindrome
# t= 112 s= 211
# not a palindrome
# t= 113 s= 311
# not a palindrome
# t= 114 s= 411
# not a palindrome
# t= 115 s= 511
# not a palindrome
# t= 116 s= 611
# not a palindrome
# t= 117 s= 711
# not a palindrome
# t= 118 s= 811
# not a palindrome
# t= 119 s= 911
# not a palindrome
# t= 120 s= 21
# not a palindrome
# t= 121 s= 121
# 121 is a palindrome
# t= 122 s= 221
# not a palindrome
# t= 123 s= 321
# not a palindrome
# t= 124 s= 421
# not a palindrome
# t= 125 s= 521
# not a palindrome
# t= 126 s= 621
# not a palindrome
# t= 127 s= 721
# not a palindrome
# t= 128 s= 821
# not a palindrome
# t= 129 s= 921
# not a palindrome
# t= 130 s= 31
# not a palindrome
# t= 131 s= 131
# 131 is a palindrome
# t= 132 s= 231
# not a palindrome
# t= 133 s= 331
# not a palindrome
# t= 134 s= 431
# not a palindrome
# t= 135 s= 531
# not a palindrome
# t= 136 s= 631
# not a palindrome
# t= 137 s= 731
# not a palindrome
# t= 138 s= 831
# not a palindrome
# t= 139 s= 931
# not a palindrome
# t= 140 s= 41
# not a palindrome
# t= 141 s= 141
# 141 is a palindrome
# t= 142 s= 241
# not a palindrome
# t= 143 s= 341
# not a palindrome
# t= 144 s= 441
# not a palindrome
# t= 145 s= 541
# not a palindrome
# t= 146 s= 641
# not a palindrome
# t= 147 s= 741
# not a palindrome
# t= 148 s= 841
# not a palindrome
# t= 149 s= 941
# not a palindrome
# t= 150 s= 51
# not a palindrome
# t= 151 s= 151
# 151 is a palindrome
# t= 152 s= 251
# not a palindrome
# t= 153 s= 351
# not a palindrome
# t= 154 s= 451
# not a palindrome
# t= 155 s= 551
# not a palindrome
# t= 156 s= 651
# not a palindrome
# t= 157 s= 751
# not a palindrome
# t= 158 s= 851
# not a palindrome
# t= 159 s= 951
# not a palindrome
# t= 160 s= 61
# not a palindrome
# t= 161 s= 161
# 161 is a palindrome
# t= 162 s= 261
# not a palindrome
# t= 163 s= 361
# not a palindrome
# t= 164 s= 461
# not a palindrome
# t= 165 s= 561
# not a palindrome
# t= 166 s= 661
# not a palindrome
# t= 167 s= 761
# not a palindrome
# t= 168 s= 861
# not a palindrome
# t= 169 s= 961
# not a palindrome
# t= 170 s= 71
# not a palindrome
# t= 171 s= 171
# 171 is a palindrome
# t= 172 s= 271
# not a palindrome
# t= 173 s= 371
# not a palindrome
# t= 174 s= 471
# not a palindrome
# t= 175 s= 571
# not a palindrome
# t= 176 s= 671
# not a palindrome
# t= 177 s= 771
# not a palindrome
# t= 178 s= 871
# not a palindrome
# t= 179 s= 971
# not a palindrome
# t= 180 s= 81
# not a palindrome
# t= 181 s= 181
# 181 is a palindrome
# t= 182 s= 281
# not a palindrome
# t= 183 s= 381
# not a palindrome
# t= 184 s= 481
# not a palindrome
# t= 185 s= 581
# not a palindrome
# t= 186 s= 681
# not a palindrome
# t= 187 s= 781
# not a palindrome
# t= 188 s= 881
# not a palindrome
# t= 189 s= 981
# not a palindrome
# t= 190 s= 91
# not a palindrome
# t= 191 s= 191
# 191 is a palindrome
# t= 192 s= 291
# not a palindrome
# t= 193 s= 391
# not a palindrome
# t= 194 s= 491
# not a palindrome
# t= 195 s= 591
# not a palindrome
# t= 196 s= 691
# not a palindrome
# t= 197 s= 791
# not a palindrome
# t= 198 s= 891
# not a palindrome
# t= 199 s= 991
# not a palindrome
# t= 200 s= 2
# not a palindrome
# t= 201 s= 102
# not a palindrome
# t= 202 s= 202
# 202 is a palindrome
# t= 203 s= 302
# not a palindrome
# t= 204 s= 402
# not a palindrome
# t= 205 s= 502
# not a palindrome
# t= 206 s= 602
# not a palindrome
# t= 207 s= 702
# not a palindrome
# t= 208 s= 802
# not a palindrome
# t= 209 s= 902
# not a palindrome
# t= 210 s= 12
# not a palindrome
# t= 211 s= 112
# not a palindrome
# t= 212 s= 212
# 212 is a palindrome
# t= 213 s= 312
# not a palindrome
# t= 214 s= 412
# not a palindrome
# t= 215 s= 512
# not a palindrome
# t= 216 s= 612
# not a palindrome
# t= 217 s= 712
# not a palindrome
# t= 218 s= 812
# not a palindrome
# t= 219 s= 912
# not a palindrome
# t= 220 s= 22
# not a palindrome
# t= 221 s= 122
# not a palindrome
# t= 222 s= 222
# 222 is a palindrome
# t= 223 s= 322
# not a palindrome
# t= 224 s= 422
# not a palindrome
# t= 225 s= 522
# not a palindrome
# t= 226 s= 622
# not a palindrome
# t= 227 s= 722
# not a palindrome
# t= 228 s= 822
# not a palindrome
# t= 229 s= 922
# not a palindrome
# t= 230 s= 32
# not a palindrome
# t= 231 s= 132
# not a palindrome
# t= 232 s= 232
# 232 is a palindrome
# t= 233 s= 332
# not a palindrome
# t= 234 s= 432
# not a palindrome
# t= 235 s= 532
# not a palindrome
# t= 236 s= 632
# not a palindrome
# t= 237 s= 732
# not a palindrome
# t= 238 s= 832
# not a palindrome
# t= 239 s= 932
# not a palindrome
# t= 240 s= 42
# not a palindrome
# t= 241 s= 142
# not a palindrome
# t= 242 s= 242
# 242 is a palindrome
# t= 243 s= 342
# not a palindrome
# t= 244 s= 442
# not a palindrome
# t= 245 s= 542
# not a palindrome
# t= 246 s= 642
# not a palindrome
# t= 247 s= 742
# not a palindrome
# t= 248 s= 842
# not a palindrome
# t= 249 s= 942
# not a palindrome
# t= 250 s= 52
# not a palindrome
# t= 251 s= 152
# not a palindrome
# t= 252 s= 252
# 252 is a palindrome
# t= 253 s= 352
# not a palindrome
# t= 254 s= 452
# not a palindrome
# t= 255 s= 552
# not a palindrome
# t= 256 s= 652
# not a palindrome
# t= 257 s= 752
# not a palindrome
# t= 258 s= 852
# not a palindrome
# t= 259 s= 952
# not a palindrome
# t= 260 s= 62
# not a palindrome
# t= 261 s= 162
# not a palindrome
# t= 262 s= 262
# 262 is a palindrome
# t= 263 s= 362
# not a palindrome
# t= 264 s= 462
# not a palindrome
# t= 265 s= 562
# not a palindrome
# t= 266 s= 662
# not a palindrome
# t= 267 s= 762
# not a palindrome
# t= 268 s= 862
# not a palindrome
# t= 269 s= 962
# not a palindrome
# t= 270 s= 72
# not a palindrome
# t= 271 s= 172
# not a palindrome
# t= 272 s= 272
# 272 is a palindrome
# t= 273 s= 372
# not a palindrome
# t= 274 s= 472
# not a palindrome
# t= 275 s= 572
# not a palindrome
# t= 276 s= 672
# not a palindrome
# t= 277 s= 772
# not a palindrome
# t= 278 s= 872
# not a palindrome
# t= 279 s= 972
# not a palindrome
# t= 280 s= 82
# not a palindrome
# t= 281 s= 182
# not a palindrome
# t= 282 s= 282
# 282 is a palindrome
# t= 283 s= 382
# not a palindrome
# t= 284 s= 482
# not a palindrome
# t= 285 s= 582
# not a palindrome
# t= 286 s= 682
# not a palindrome
# t= 287 s= 782
# not a palindrome
# t= 288 s= 882
# not a palindrome
# t= 289 s= 982
# not a palindrome
# t= 290 s= 92
# not a palindrome
# t= 291 s= 192
# not a palindrome
# t= 292 s= 292
# 292 is a palindrome
# t= 293 s= 392
# not a palindrome
# t= 294 s= 492
# not a palindrome
# t= 295 s= 592
# not a palindrome
# t= 296 s= 692
# not a palindrome
# t= 297 s= 792
# not a palindrome
# t= 298 s= 892
# not a palindrome
# t= 299 s= 992
# not a palindrome
# t= 300 s= 3
# not a palindrome
# t= 301 s= 103
# not a palindrome
# t= 302 s= 203
# not a palindrome
# t= 303 s= 303
# 303 is a palindrome
# t= 304 s= 403
# not a palindrome
# t= 305 s= 503
# not a palindrome
# t= 306 s= 603
# not a palindrome
# t= 307 s= 703
# not a palindrome
# t= 308 s= 803
# not a palindrome
# t= 309 s= 903
# not a palindrome
# t= 310 s= 13
# not a palindrome
# t= 311 s= 113
# not a palindrome
# t= 312 s= 213
# not a palindrome
# t= 313 s= 313
# 313 is a palindrome
# t= 314 s= 413
# not a palindrome
# t= 315 s= 513
# not a palindrome
# t= 316 s= 613
# not a palindrome
# t= 317 s= 713
# not a palindrome
# t= 318 s= 813
# not a palindrome
# t= 319 s= 913
# not a palindrome
# t= 320 s= 23
# not a palindrome
# t= 321 s= 123
# not a palindrome
# t= 322 s= 223
# not a palindrome
# t= 323 s= 323
# 323 is a palindrome
# t= 324 s= 423
# not a palindrome
# t= 325 s= 523
# not a palindrome
# t= 326 s= 623
# not a palindrome
# t= 327 s= 723
# not a palindrome
# t= 328 s= 823
# not a palindrome
# t= 329 s= 923
# not a palindrome
# t= 330 s= 33
# not a palindrome
# t= 331 s= 133
# not a palindrome
# t= 332 s= 233
# not a palindrome
# t= 333 s= 333
# 333 is a palindrome
# t= 334 s= 433
# not a palindrome
# t= 335 s= 533
# not a palindrome
# t= 336 s= 633
# not a palindrome
# t= 337 s= 733
# not a palindrome
# t= 338 s= 833
# not a palindrome
# t= 339 s= 933
# not a palindrome
# t= 340 s= 43
# not a palindrome
# t= 341 s= 143
# not a palindrome
# t= 342 s= 243
# not a palindrome
# t= 343 s= 343
# 343 is a palindrome
# t= 344 s= 443
# not a palindrome
# t= 345 s= 543
# not a palindrome
# t= 346 s= 643
# not a palindrome
# t= 347 s= 743
# not a palindrome
# t= 348 s= 843
# not a palindrome
# t= 349 s= 943
# not a palindrome
# t= 350 s= 53
# not a palindrome
# t= 351 s= 153
# not a palindrome
# t= 352 s= 253
# not a palindrome
# t= 353 s= 353
# 353 is a palindrome
# t= 354 s= 453
# not a palindrome
# t= 355 s= 553
# not a palindrome
# t= 356 s= 653
# not a palindrome
# t= 357 s= 753
# not a palindrome
# t= 358 s= 853
# not a palindrome
# t= 359 s= 953
# not a palindrome
# t= 360 s= 63
# not a palindrome
# t= 361 s= 163
# not a palindrome
# t= 362 s= 263
# not a palindrome
# t= 363 s= 363
# 363 is a palindrome
# t= 364 s= 463
# not a palindrome
# t= 365 s= 563
# not a palindrome
# t= 366 s= 663
# not a palindrome
# t= 367 s= 763
# not a palindrome
# t= 368 s= 863
# not a palindrome
# t= 369 s= 963
# not a palindrome
# t= 370 s= 73
# not a palindrome
# t= 371 s= 173
# not a palindrome
# t= 372 s= 273
# not a palindrome
# t= 373 s= 373
# 373 is a palindrome
# t= 374 s= 473
# not a palindrome
# t= 375 s= 573
# not a palindrome
# t= 376 s= 673
# not a palindrome
# t= 377 s= 773
# not a palindrome
# t= 378 s= 873
# not a palindrome
# t= 379 s= 973
# not a palindrome
# t= 380 s= 83
# not a palindrome
# t= 381 s= 183
# not a palindrome
# t= 382 s= 283
# not a palindrome
# t= 383 s= 383
# 383 is a palindrome
# t= 384 s= 483
# not a palindrome
# t= 385 s= 583
# not a palindrome
# t= 386 s= 683
# not a palindrome
# t= 387 s= 783
# not a palindrome
# t= 388 s= 883
# not a palindrome
# t= 389 s= 983
# not a palindrome
# t= 390 s= 93
# not a palindrome
# t= 391 s= 193
# not a palindrome
# t= 392 s= 293
# not a palindrome
# t= 393 s= 393
# 393 is a palindrome
# t= 394 s= 493
# not a palindrome
# t= 395 s= 593
# not a palindrome
# t= 396 s= 693
# not a palindrome
# t= 397 s= 793
# not a palindrome
# t= 398 s= 893
# not a palindrome
# t= 399 s= 993
# not a palindrome
# t= 400 s= 4
# not a palindrome
# t= 401 s= 104
# not a palindrome
# t= 402 s= 204
# not a palindrome
# t= 403 s= 304
# not a palindrome
# t= 404 s= 404
# 404 is a palindrome
# t= 405 s= 504
# not a palindrome
# t= 406 s= 604
# not a palindrome
# t= 407 s= 704
# not a palindrome
# t= 408 s= 804
# not a palindrome
# t= 409 s= 904
# not a palindrome
# t= 410 s= 14
# not a palindrome
# t= 411 s= 114
# not a palindrome
# t= 412 s= 214
# not a palindrome
# t= 413 s= 314
# not a palindrome
# t= 414 s= 414
# 414 is a palindrome
# t= 415 s= 514
# not a palindrome
# t= 416 s= 614
# not a palindrome
# t= 417 s= 714
# not a palindrome
# t= 418 s= 814
# not a palindrome
# t= 419 s= 914
# not a palindrome
# t= 420 s= 24
# not a palindrome
# t= 421 s= 124
# not a palindrome
# t= 422 s= 224
# not a palindrome
# t= 423 s= 324
# not a palindrome
# t= 424 s= 424
# 424 is a palindrome
# t= 425 s= 524
# not a palindrome
# t= 426 s= 624
# not a palindrome
# t= 427 s= 724
# not a palindrome
# t= 428 s= 824
# not a palindrome
# t= 429 s= 924
# not a palindrome
# t= 430 s= 34
# not a palindrome
# t= 431 s= 134
# not a palindrome
# t= 432 s= 234
# not a palindrome
# t= 433 s= 334
# not a palindrome
# t= 434 s= 434
# 434 is a palindrome
# t= 435 s= 534
# not a palindrome
# t= 436 s= 634
# not a palindrome
# t= 437 s= 734
# not a palindrome
# t= 438 s= 834
# not a palindrome
# t= 439 s= 934
# not a palindrome
# t= 440 s= 44
# not a palindrome
# t= 441 s= 144
# not a palindrome
# t= 442 s= 244
# not a palindrome
# t= 443 s= 344
# not a palindrome
# t= 444 s= 444
# 444 is a palindrome
# t= 445 s= 544
# not a palindrome
# t= 446 s= 644
# not a palindrome
# t= 447 s= 744
# not a palindrome
# t= 448 s= 844
# not a palindrome
# t= 449 s= 944
# not a palindrome
# t= 450 s= 54
# not a palindrome
# t= 451 s= 154
# not a palindrome
# t= 452 s= 254
# not a palindrome
# t= 453 s= 354
# not a palindrome
# t= 454 s= 454
# 454 is a palindrome
# t= 455 s= 554
# not a palindrome
# t= 456 s= 654
# not a palindrome
# t= 457 s= 754
# not a palindrome
# t= 458 s= 854
# not a palindrome
# t= 459 s= 954
# not a palindrome
# t= 460 s= 64
# not a palindrome
# t= 461 s= 164
# not a palindrome
# t= 462 s= 264
# not a palindrome
# t= 463 s= 364
# not a palindrome
# t= 464 s= 464
# 464 is a palindrome
# t= 465 s= 564
# not a palindrome
# t= 466 s= 664
# not a palindrome
# t= 467 s= 764
# not a palindrome
# t= 468 s= 864
# not a palindrome
# t= 469 s= 964
# not a palindrome
# t= 470 s= 74
# not a palindrome
# t= 471 s= 174
# not a palindrome
# t= 472 s= 274
# not a palindrome
# t= 473 s= 374
# not a palindrome
# t= 474 s= 474
# 474 is a palindrome
# t= 475 s= 574
# not a palindrome
# t= 476 s= 674
# not a palindrome
# t= 477 s= 774
# not a palindrome
# t= 478 s= 874
# not a palindrome
# t= 479 s= 974
# not a palindrome
# t= 480 s= 84
# not a palindrome
# t= 481 s= 184
# not a palindrome
# t= 482 s= 284
# not a palindrome
# t= 483 s= 384
# not a palindrome
# t= 484 s= 484
# 484 is a palindrome
# t= 485 s= 584
# not a palindrome
# t= 486 s= 684
# not a palindrome
# t= 487 s= 784
# not a palindrome
# t= 488 s= 884
# not a palindrome
# t= 489 s= 984
# not a palindrome
# t= 490 s= 94
# not a palindrome
# t= 491 s= 194
# not a palindrome
# t= 492 s= 294
# not a palindrome
# t= 493 s= 394
# not a palindrome
# t= 494 s= 494
# 494 is a palindrome
# t= 495 s= 594
# not a palindrome
# t= 496 s= 694
# not a palindrome
# t= 497 s= 794
# not a palindrome
# t= 498 s= 894
# not a palindrome
# t= 499 s= 994
# not a palindrome
# t= 500 s= 5
# not a palindrome
# t= 501 s= 105
# not a palindrome
# t= 502 s= 205
# not a palindrome
# t= 503 s= 305
# not a palindrome
# t= 504 s= 405
# not a palindrome
# t= 505 s= 505
# 505 is a palindrome
# t= 506 s= 605
# not a palindrome
# t= 507 s= 705
# not a palindrome
# t= 508 s= 805
# not a palindrome
# t= 509 s= 905
# not a palindrome
# t= 510 s= 15
# not a palindrome
# t= 511 s= 115
# not a palindrome
# t= 512 s= 215
# not a palindrome
# t= 513 s= 315
# not a palindrome
# t= 514 s= 415
# not a palindrome
# t= 515 s= 515
# 515 is a palindrome
# t= 516 s= 615
# not a palindrome
# t= 517 s= 715
# not a palindrome
# t= 518 s= 815
# not a palindrome
# t= 519 s= 915
# not a palindrome
# t= 520 s= 25
# not a palindrome
# t= 521 s= 125
# not a palindrome
# t= 522 s= 225
# not a palindrome
# t= 523 s= 325
# not a palindrome
# t= 524 s= 425
# not a palindrome
# t= 525 s= 525
# 525 is a palindrome
# t= 526 s= 625
# not a palindrome
# t= 527 s= 725
# not a palindrome
# t= 528 s= 825
# not a palindrome
# t= 529 s= 925
# not a palindrome
# t= 530 s= 35
# not a palindrome
# t= 531 s= 135
# not a palindrome
# t= 532 s= 235
# not a palindrome
# t= 533 s= 335
# not a palindrome
# t= 534 s= 435
# not a palindrome
# t= 535 s= 535
# 535 is a palindrome
# t= 536 s= 635
# not a palindrome
# t= 537 s= 735
# not a palindrome
# t= 538 s= 835
# not a palindrome
# t= 539 s= 935
# not a palindrome
# t= 540 s= 45
# not a palindrome
# t= 541 s= 145
# not a palindrome
# t= 542 s= 245
# not a palindrome
# t= 543 s= 345
# not a palindrome
# t= 544 s= 445
# not a palindrome
# t= 545 s= 545
# 545 is a palindrome
# t= 546 s= 645
# not a palindrome
# t= 547 s= 745
# not a palindrome
# t= 548 s= 845
# not a palindrome
# t= 549 s= 945
# not a palindrome
# t= 550 s= 55
# not a palindrome
# t= 551 s= 155
# not a palindrome
# t= 552 s= 255
# not a palindrome
# t= 553 s= 355
# not a palindrome
# t= 554 s= 455
# not a palindrome
# t= 555 s= 555
# 555 is a palindrome
# t= 556 s= 655
# not a palindrome
# t= 557 s= 755
# not a palindrome
# t= 558 s= 855
# not a palindrome
# t= 559 s= 955
# not a palindrome
# t= 560 s= 65
# not a palindrome
# t= 561 s= 165
# not a palindrome
# t= 562 s= 265
# not a palindrome
# t= 563 s= 365
# not a palindrome
# t= 564 s= 465
# not a palindrome
# t= 565 s= 565
# 565 is a palindrome
# t= 566 s= 665
# not a palindrome
# t= 567 s= 765
# not a palindrome
# t= 568 s= 865
# not a palindrome
# t= 569 s= 965
# not a palindrome
# t= 570 s= 75
# not a palindrome
# t= 571 s= 175
# not a palindrome
# t= 572 s= 275
# not a palindrome
# t= 573 s= 375
# not a palindrome
# t= 574 s= 475
# not a palindrome
# t= 575 s= 575
# 575 is a palindrome
# t= 576 s= 675
# not a palindrome
# t= 577 s= 775
# not a palindrome
# t= 578 s= 875
# not a palindrome
# t= 579 s= 975
# not a palindrome
# t= 580 s= 85
# not a palindrome
# t= 581 s= 185
# not a palindrome
# t= 582 s= 285
# not a palindrome
# t= 583 s= 385
# not a palindrome
# t= 584 s= 485
# not a palindrome
# t= 585 s= 585
# 585 is a palindrome
# t= 586 s= 685
# not a palindrome
# t= 587 s= 785
# not a palindrome
# t= 588 s= 885
# not a palindrome
# t= 589 s= 985
# not a palindrome
# t= 590 s= 95
# not a palindrome
# t= 591 s= 195
# not a palindrome
# t= 592 s= 295
# not a palindrome
# t= 593 s= 395
# not a palindrome
# t= 594 s= 495
# not a palindrome
# t= 595 s= 595
# 595 is a palindrome
# t= 596 s= 695
# not a palindrome
# t= 597 s= 795
# not a palindrome
# t= 598 s= 895
# not a palindrome
# t= 599 s= 995
# not a palindrome
# t= 600 s= 6
# not a palindrome
# t= 601 s= 106
# not a palindrome
# t= 602 s= 206
# not a palindrome
# t= 603 s= 306
# not a palindrome
# t= 604 s= 406
# not a palindrome
# t= 605 s= 506
# not a palindrome
# t= 606 s= 606
# 606 is a palindrome
# t= 607 s= 706
# not a palindrome
# t= 608 s= 806
# not a palindrome
# t= 609 s= 906
# not a palindrome
# t= 610 s= 16
# not a palindrome
# t= 611 s= 116
# not a palindrome
# t= 612 s= 216
# not a palindrome
# t= 613 s= 316
# not a palindrome
# t= 614 s= 416
# not a palindrome
# t= 615 s= 516
# not a palindrome
# t= 616 s= 616
# 616 is a palindrome
# t= 617 s= 716
# not a palindrome
# t= 618 s= 816
# not a palindrome
# t= 619 s= 916
# not a palindrome
# t= 620 s= 26
# not a palindrome
# t= 621 s= 126
# not a palindrome
# t= 622 s= 226
# not a palindrome
# t= 623 s= 326
# not a palindrome
# t= 624 s= 426
# not a palindrome
# t= 625 s= 526
# not a palindrome
# t= 626 s= 626
# 626 is a palindrome
# t= 627 s= 726
# not a palindrome
# t= 628 s= 826
# not a palindrome
# t= 629 s= 926
# not a palindrome
# t= 630 s= 36
# not a palindrome
# t= 631 s= 136
# not a palindrome
# t= 632 s= 236
# not a palindrome
# t= 633 s= 336
# not a palindrome
# t= 634 s= 436
# not a palindrome
# t= 635 s= 536
# not a palindrome
# t= 636 s= 636
# 636 is a palindrome
# t= 637 s= 736
# not a palindrome
# t= 638 s= 836
# not a palindrome
# t= 639 s= 936
# not a palindrome
# t= 640 s= 46
# not a palindrome
# t= 641 s= 146
# not a palindrome
# t= 642 s= 246
# not a palindrome
# t= 643 s= 346
# not a palindrome
# t= 644 s= 446
# not a palindrome
# t= 645 s= 546
# not a palindrome
# t= 646 s= 646
# 646 is a palindrome
# t= 647 s= 746
# not a palindrome
# t= 648 s= 846
# not a palindrome
# t= 649 s= 946
# not a palindrome
# t= 650 s= 56
# not a palindrome
# t= 651 s= 156
# not a palindrome
# t= 652 s= 256
# not a palindrome
# t= 653 s= 356
# not a palindrome
# t= 654 s= 456
# not a palindrome
# t= 655 s= 556
# not a palindrome
# t= 656 s= 656
# 656 is a palindrome
# t= 657 s= 756
# not a palindrome
# t= 658 s= 856
# not a palindrome
# t= 659 s= 956
# not a palindrome
# t= 660 s= 66
# not a palindrome
# t= 661 s= 166
# not a palindrome
# t= 662 s= 266
# not a palindrome
# t= 663 s= 366
# not a palindrome
# t= 664 s= 466
# not a palindrome
# t= 665 s= 566
# not a palindrome
# t= 666 s= 666
# 666 is a palindrome
# t= 667 s= 766
# not a palindrome
# t= 668 s= 866
# not a palindrome
# t= 669 s= 966
# not a palindrome
# t= 670 s= 76
# not a palindrome
# t= 671 s= 176
# not a palindrome
# t= 672 s= 276
# not a palindrome
# t= 673 s= 376
# not a palindrome
# t= 674 s= 476
# not a palindrome
# t= 675 s= 576
# not a palindrome
# t= 676 s= 676
# 676 is a palindrome
# t= 677 s= 776
# not a palindrome
# t= 678 s= 876
# not a palindrome
# t= 679 s= 976
# not a palindrome
# t= 680 s= 86
# not a palindrome
# t= 681 s= 186
# not a palindrome
# t= 682 s= 286
# not a palindrome
# t= 683 s= 386
# not a palindrome
# t= 684 s= 486
# not a palindrome
# t= 685 s= 586
# not a palindrome
# t= 686 s= 686
# 686 is a palindrome
# t= 687 s= 786
# not a palindrome
# t= 688 s= 886
# not a palindrome
# t= 689 s= 986
# not a palindrome
# t= 690 s= 96
# not a palindrome
# t= 691 s= 196
# not a palindrome
# t= 692 s= 296
# not a palindrome
# t= 693 s= 396
# not a palindrome
# t= 694 s= 496
# not a palindrome
# t= 695 s= 596
# not a palindrome
# t= 696 s= 696
# 696 is a palindrome
# t= 697 s= 796
# not a palindrome
# t= 698 s= 896
# not a palindrome
# t= 699 s= 996
# not a palindrome
# t= 700 s= 7
# not a palindrome
# t= 701 s= 107
# not a palindrome
# t= 702 s= 207
# not a palindrome
# t= 703 s= 307
# not a palindrome
# t= 704 s= 407
# not a palindrome
# t= 705 s= 507
# not a palindrome
# t= 706 s= 607
# not a palindrome
# t= 707 s= 707
# 707 is a palindrome
# t= 708 s= 807
# not a palindrome
# t= 709 s= 907
# not a palindrome
# t= 710 s= 17
# not a palindrome
# t= 711 s= 117
# not a palindrome
# t= 712 s= 217
# not a palindrome
# t= 713 s= 317
# not a palindrome
# t= 714 s= 417
# not a palindrome
# t= 715 s= 517
# not a palindrome
# t= 716 s= 617
# not a palindrome
# t= 717 s= 717
# 717 is a palindrome
# t= 718 s= 817
# not a palindrome
# t= 719 s= 917
# not a palindrome
# t= 720 s= 27
# not a palindrome
# t= 721 s= 127
# not a palindrome
# t= 722 s= 227
# not a palindrome
# t= 723 s= 327
# not a palindrome
# t= 724 s= 427
# not a palindrome
# t= 725 s= 527
# not a palindrome
# t= 726 s= 627
# not a palindrome
# t= 727 s= 727
# 727 is a palindrome
# t= 728 s= 827
# not a palindrome
# t= 729 s= 927
# not a palindrome
# t= 730 s= 37
# not a palindrome
# t= 731 s= 137
# not a palindrome
# t= 732 s= 237
# not a palindrome
# t= 733 s= 337
# not a palindrome
# t= 734 s= 437
# not a palindrome
# t= 735 s= 537
# not a palindrome
# t= 736 s= 637
# not a palindrome
# t= 737 s= 737
# 737 is a palindrome
# t= 738 s= 837
# not a palindrome
# t= 739 s= 937
# not a palindrome
# t= 740 s= 47
# not a palindrome
# t= 741 s= 147
# not a palindrome
# t= 742 s= 247
# not a palindrome
# t= 743 s= 347
# not a palindrome
# t= 744 s= 447
# not a palindrome
# t= 745 s= 547
# not a palindrome
# t= 746 s= 647
# not a palindrome
# t= 747 s= 747
# 747 is a palindrome
# t= 748 s= 847
# not a palindrome
# t= 749 s= 947
# not a palindrome
# t= 750 s= 57
# not a palindrome
# t= 751 s= 157
# not a palindrome
# t= 752 s= 257
# not a palindrome
# t= 753 s= 357
# not a palindrome
# t= 754 s= 457
# not a palindrome
# t= 755 s= 557
# not a palindrome
# t= 756 s= 657
# not a palindrome
# t= 757 s= 757
# 757 is a palindrome
# t= 758 s= 857
# not a palindrome
# t= 759 s= 957
# not a palindrome
# t= 760 s= 67
# not a palindrome
# t= 761 s= 167
# not a palindrome
# t= 762 s= 267
# not a palindrome
# t= 763 s= 367
# not a palindrome
# t= 764 s= 467
# not a palindrome
# t= 765 s= 567
# not a palindrome
# t= 766 s= 667
# not a palindrome
# t= 767 s= 767
# 767 is a palindrome
# t= 768 s= 867
# not a palindrome
# t= 769 s= 967
# not a palindrome
# t= 770 s= 77
# not a palindrome
# t= 771 s= 177
# not a palindrome
# t= 772 s= 277
# not a palindrome
# t= 773 s= 377
# not a palindrome
# t= 774 s= 477
# not a palindrome
# t= 775 s= 577
# not a palindrome
# t= 776 s= 677
# not a palindrome
# t= 777 s= 777
# 777 is a palindrome
# t= 778 s= 877
# not a palindrome
# t= 779 s= 977
# not a palindrome
# t= 780 s= 87
# not a palindrome
# t= 781 s= 187
# not a palindrome
# t= 782 s= 287
# not a palindrome
# t= 783 s= 387
# not a palindrome
# t= 784 s= 487
# not a palindrome
# t= 785 s= 587
# not a palindrome
# t= 786 s= 687
# not a palindrome
# t= 787 s= 787
# 787 is a palindrome
# t= 788 s= 887
# not a palindrome
# t= 789 s= 987
# not a palindrome
# t= 790 s= 97
# not a palindrome
# t= 791 s= 197
# not a palindrome
# t= 792 s= 297
# not a palindrome
# t= 793 s= 397
# not a palindrome
# t= 794 s= 497
# not a palindrome
# t= 795 s= 597
# not a palindrome
# t= 796 s= 697
# not a palindrome
# t= 797 s= 797
# 797 is a palindrome
# t= 798 s= 897
# not a palindrome
# t= 799 s= 997
# not a palindrome
# t= 800 s= 8
# not a palindrome
# t= 801 s= 108
# not a palindrome
# t= 802 s= 208
# not a palindrome
# t= 803 s= 308
# not a palindrome
# t= 804 s= 408
# not a palindrome
# t= 805 s= 508
# not a palindrome
# t= 806 s= 608
# not a palindrome
# t= 807 s= 708
# not a palindrome
# t= 808 s= 808
# 808 is a palindrome
# t= 809 s= 908
# not a palindrome
# t= 810 s= 18
# not a palindrome
# t= 811 s= 118
# not a palindrome
# t= 812 s= 218
# not a palindrome
# t= 813 s= 318
# not a palindrome
# t= 814 s= 418
# not a palindrome
# t= 815 s= 518
# not a palindrome
# t= 816 s= 618
# not a palindrome
# t= 817 s= 718
# not a palindrome
# t= 818 s= 818
# 818 is a palindrome
# t= 819 s= 918
# not a palindrome
# t= 820 s= 28
# not a palindrome
# t= 821 s= 128
# not a palindrome
# t= 822 s= 228
# not a palindrome
# t= 823 s= 328
# not a palindrome
# t= 824 s= 428
# not a palindrome
# t= 825 s= 528
# not a palindrome
# t= 826 s= 628
# not a palindrome
# t= 827 s= 728
# not a palindrome
# t= 828 s= 828
# 828 is a palindrome
# t= 829 s= 928
# not a palindrome
# t= 830 s= 38
# not a palindrome
# t= 831 s= 138
# not a palindrome
# t= 832 s= 238
# not a palindrome
# t= 833 s= 338
# not a palindrome
# t= 834 s= 438
# not a palindrome
# t= 835 s= 538
# not a palindrome
# t= 836 s= 638
# not a palindrome
# t= 837 s= 738
# not a palindrome
# t= 838 s= 838
# 838 is a palindrome
# t= 839 s= 938
# not a palindrome
# t= 840 s= 48
# not a palindrome
# t= 841 s= 148
# not a palindrome
# t= 842 s= 248
# not a palindrome
# t= 843 s= 348
# not a palindrome
# t= 844 s= 448
# not a palindrome
# t= 845 s= 548
# not a palindrome
# t= 846 s= 648
# not a palindrome
# t= 847 s= 748
# not a palindrome
# t= 848 s= 848
# 848 is a palindrome
# t= 849 s= 948
# not a palindrome
# t= 850 s= 58
# not a palindrome
# t= 851 s= 158
# not a palindrome
# t= 852 s= 258
# not a palindrome
# t= 853 s= 358
# not a palindrome
# t= 854 s= 458
# not a palindrome
# t= 855 s= 558
# not a palindrome
# t= 856 s= 658
# not a palindrome
# t= 857 s= 758
# not a palindrome
# t= 858 s= 858
# 858 is a palindrome
# t= 859 s= 958
# not a palindrome
# t= 860 s= 68
# not a palindrome
# t= 861 s= 168
# not a palindrome
# t= 862 s= 268
# not a palindrome
# t= 863 s= 368
# not a palindrome
# t= 864 s= 468
# not a palindrome
# t= 865 s= 568
# not a palindrome
# t= 866 s= 668
# not a palindrome
# t= 867 s= 768
# not a palindrome
# t= 868 s= 868
# 868 is a palindrome
# t= 869 s= 968
# not a palindrome
# t= 870 s= 78
# not a palindrome
# t= 871 s= 178
# not a palindrome
# t= 872 s= 278
# not a palindrome
# t= 873 s= 378
# not a palindrome
# t= 874 s= 478
# not a palindrome
# t= 875 s= 578
# not a palindrome
# t= 876 s= 678
# not a palindrome
# t= 877 s= 778
# not a palindrome
# t= 878 s= 878
# 878 is a palindrome
# t= 879 s= 978
# not a palindrome
# t= 880 s= 88
# not a palindrome
# t= 881 s= 188
# not a palindrome
# t= 882 s= 288
# not a palindrome
# t= 883 s= 388
# not a palindrome
# t= 884 s= 488
# not a palindrome
# t= 885 s= 588
# not a palindrome
# t= 886 s= 688
# not a palindrome
# t= 887 s= 788
# not a palindrome
# t= 888 s= 888
# 888 is a palindrome
# t= 889 s= 988
# not a palindrome
# t= 890 s= 98
# not a palindrome
# t= 891 s= 198
# not a palindrome
# t= 892 s= 298
# not a palindrome
# t= 893 s= 398
# not a palindrome
# t= 894 s= 498
# not a palindrome
# t= 895 s= 598
# not a palindrome
# t= 896 s= 698
# not a palindrome
# t= 897 s= 798
# not a palindrome
# t= 898 s= 898
# 898 is a palindrome
# t= 899 s= 998
# not a palindrome
# t= 900 s= 9
# not a palindrome
# t= 901 s= 109
# not a palindrome
# t= 902 s= 209
# not a palindrome
# t= 903 s= 309
# not a palindrome
# t= 904 s= 409
# not a palindrome
# t= 905 s= 509
# not a palindrome
# t= 906 s= 609
# not a palindrome
# t= 907 s= 709
# not a palindrome
# t= 908 s= 809
# not a palindrome
# t= 909 s= 909
# 909 is a palindrome
# t= 910 s= 19
# not a palindrome
# t= 911 s= 119
# not a palindrome
# t= 912 s= 219
# not a palindrome
# t= 913 s= 319
# not a palindrome
# t= 914 s= 419
# not a palindrome
# t= 915 s= 519
# not a palindrome
# t= 916 s= 619
# not a palindrome
# t= 917 s= 719
# not a palindrome
# t= 918 s= 819
# not a palindrome
# t= 919 s= 919
# 919 is a palindrome
# t= 920 s= 29
# not a palindrome
# t= 921 s= 129
# not a palindrome
# t= 922 s= 229
# not a palindrome
# t= 923 s= 329
# not a palindrome
# t= 924 s= 429
# not a palindrome
# t= 925 s= 529
# not a palindrome
# t= 926 s= 629
# not a palindrome
# t= 927 s= 729
# not a palindrome
# t= 928 s= 829
# not a palindrome
# t= 929 s= 929
# 929 is a palindrome
# t= 930 s= 39
# not a palindrome
# t= 931 s= 139
# not a palindrome
# t= 932 s= 239
# not a palindrome
# t= 933 s= 339
# not a palindrome
# t= 934 s= 439
# not a palindrome
# t= 935 s= 539
# not a palindrome
# t= 936 s= 639
# not a palindrome
# t= 937 s= 739
# not a palindrome
# t= 938 s= 839
# not a palindrome
# t= 939 s= 939
# 939 is a palindrome
# t= 940 s= 49
# not a palindrome
# t= 941 s= 149
# not a palindrome
# t= 942 s= 249
# not a palindrome
# t= 943 s= 349
# not a palindrome
# t= 944 s= 449
# not a palindrome
# t= 945 s= 549
# not a palindrome
# t= 946 s= 649
# not a palindrome
# t= 947 s= 749
# not a palindrome
# t= 948 s= 849
# not a palindrome
# t= 949 s= 949
# 949 is a palindrome
# t= 950 s= 59
# not a palindrome
# t= 951 s= 159
# not a palindrome
# t= 952 s= 259
# not a palindrome
# t= 953 s= 359
# not a palindrome
# t= 954 s= 459
# not a palindrome
# t= 955 s= 559
# not a palindrome
# t= 956 s= 659
# not a palindrome
# t= 957 s= 759
# not a palindrome
# t= 958 s= 859
# not a palindrome
# t= 959 s= 959
# 959 is a palindrome
# t= 960 s= 69
# not a palindrome
# t= 961 s= 169
# not a palindrome
# t= 962 s= 269
# not a palindrome
# t= 963 s= 369
# not a palindrome
# t= 964 s= 469
# not a palindrome
# t= 965 s= 569
# not a palindrome
# t= 966 s= 669
# not a palindrome
# t= 967 s= 769
# not a palindrome
# t= 968 s= 869
# not a palindrome
# t= 969 s= 969
# 969 is a palindrome
# t= 970 s= 79
# not a palindrome
# t= 971 s= 179
# not a palindrome
# t= 972 s= 279
# not a palindrome
# t= 973 s= 379
# not a palindrome
# t= 974 s= 479
# not a palindrome
# t= 975 s= 579
# not a palindrome
# t= 976 s= 679
# not a palindrome
# t= 977 s= 779
# not a palindrome
# t= 978 s= 879
# not a palindrome
# t= 979 s= 979
# 979 is a palindrome
# t= 980 s= 89
# not a palindrome
# t= 981 s= 189
# not a palindrome
# t= 982 s= 289
# not a palindrome
# t= 983 s= 389
# not a palindrome
# t= 984 s= 489
# not a palindrome
# t= 985 s= 589
# not a palindrome
# t= 986 s= 689
# not a palindrome
# t= 987 s= 789
# not a palindrome
# t= 988 s= 889
# not a palindrome
# t= 989 s= 989
# 989 is a palindrome
# t= 990 s= 99
# not a palindrome
# t= 991 s= 199
# not a palindrome
# t= 992 s= 299
# not a palindrome
# t= 993 s= 399
# not a palindrome
# t= 994 s= 499
# not a palindrome
# t= 995 s= 599
# not a palindrome
# t= 996 s= 699
# not a palindrome
# t= 997 s= 799
# not a palindrome
# t= 998 s= 899
# not a palindrome
# t= 999 s= 999
# 999 is a palindrome

# %% [markdown]
# 9.	Print all Armstrong numbers between 1 to 1000.

# %%
#9
import math as mt
#n1=int(input("enter a intial value"))
#n2=int(input("enter a final value"))
c=0 
s=0
p=0
for i in range(1,1000,1):
    n=i
    t=n
    s=0
    while(n!=0):
        r=n%10
        print(r)
        s=s+(r*r*r)
        n=n//10
    print("t=",t,"s=",s)
    if(t==s):
        print(s,"is a armstrong number")
    else:
        print("not a armstrong number")
# Out:
# 1
# t= 1 s= 1
# 1 is a armstrong number
# 2
# t= 2 s= 8
# not a armstrong number
# 3
# t= 3 s= 27
# not a armstrong number
# 4
# t= 4 s= 64
# not a armstrong number
# 5
# t= 5 s= 125
# not a armstrong number
# 6
# t= 6 s= 216
# not a armstrong number
# 7
# t= 7 s= 343
# not a armstrong number
# 8
# t= 8 s= 512
# not a armstrong number
# 9
# t= 9 s= 729
# not a armstrong number
# 0
# 1
# t= 10 s= 1
# not a armstrong number
# 1
# 1
# t= 11 s= 2
# not a armstrong number
# 2
# 1
# t= 12 s= 9
# not a armstrong number
# 3
# 1
# t= 13 s= 28
# not a armstrong number
# 4
# 1
# t= 14 s= 65
# not a armstrong number
# 5
# 1
# t= 15 s= 126
# not a armstrong number
# 6
# 1
# t= 16 s= 217
# not a armstrong number
# 7
# 1
# t= 17 s= 344
# not a armstrong number
# 8
# 1
# t= 18 s= 513
# not a armstrong number
# 9
# 1
# t= 19 s= 730
# not a armstrong number
# 0
# 2
# t= 20 s= 8
# not a armstrong number
# 1
# 2
# t= 21 s= 9
# not a armstrong number
# 2
# 2
# t= 22 s= 16
# not a armstrong number
# 3
# 2
# t= 23 s= 35
# not a armstrong number
# 4
# 2
# t= 24 s= 72
# not a armstrong number
# 5
# 2
# t= 25 s= 133
# not a armstrong number
# 6
# 2
# t= 26 s= 224
# not a armstrong number
# 7
# 2
# t= 27 s= 351
# not a armstrong number
# 8
# 2
# t= 28 s= 520
# not a armstrong number
# 9
# 2
# t= 29 s= 737
# not a armstrong number
# 0
# 3
# t= 30 s= 27
# not a armstrong number
# 1
# 3
# t= 31 s= 28
# not a armstrong number
# 2
# 3
# t= 32 s= 35
# not a armstrong number
# 3
# 3
# t= 33 s= 54
# not a armstrong number
# 4
# 3
# t= 34 s= 91
# not a armstrong number
# 5
# 3
# t= 35 s= 152
# not a armstrong number
# 6
# 3
# t= 36 s= 243
# not a armstrong number
# 7
# 3
# t= 37 s= 370
# not a armstrong number
# 8
# 3
# t= 38 s= 539
# not a armstrong number
# 9
# 3
# t= 39 s= 756
# not a armstrong number
# 0
# 4
# t= 40 s= 64
# not a armstrong number
# 1
# 4
# t= 41 s= 65
# not a armstrong number
# 2
# 4
# t= 42 s= 72
# not a armstrong number
# 3
# 4
# t= 43 s= 91
# not a armstrong number
# 4
# 4
# t= 44 s= 128
# not a armstrong number
# 5
# 4
# t= 45 s= 189
# not a armstrong number
# 6
# 4
# t= 46 s= 280
# not a armstrong number
# 7
# 4
# t= 47 s= 407
# not a armstrong number
# 8
# 4
# t= 48 s= 576
# not a armstrong number
# 9
# 4
# t= 49 s= 793
# not a armstrong number
# 0
# 5
# t= 50 s= 125
# not a armstrong number
# 1
# 5
# t= 51 s= 126
# not a armstrong number
# 2
# 5
# t= 52 s= 133
# not a armstrong number
# 3
# 5
# t= 53 s= 152
# not a armstrong number
# 4
# 5
# t= 54 s= 189
# not a armstrong number
# 5
# 5
# t= 55 s= 250
# not a armstrong number
# 6
# 5
# t= 56 s= 341
# not a armstrong number
# 7
# 5
# t= 57 s= 468
# not a armstrong number
# 8
# 5
# t= 58 s= 637
# not a armstrong number
# 9
# 5
# t= 59 s= 854
# not a armstrong number
# 0
# 6
# t= 60 s= 216
# not a armstrong number
# 1
# 6
# t= 61 s= 217
# not a armstrong number
# 2
# 6
# t= 62 s= 224
# not a armstrong number
# 3
# 6
# t= 63 s= 243
# not a armstrong number
# 4
# 6
# t= 64 s= 280
# not a armstrong number
# 5
# 6
# t= 65 s= 341
# not a armstrong number
# 6
# 6
# t= 66 s= 432
# not a armstrong number
# 7
# 6
# t= 67 s= 559
# not a armstrong number
# 8
# 6
# t= 68 s= 728
# not a armstrong number
# 9
# 6
# t= 69 s= 945
# not a armstrong number
# 0
# 7
# t= 70 s= 343
# not a armstrong number
# 1
# 7
# t= 71 s= 344
# not a armstrong number
# 2
# 7
# t= 72 s= 351
# not a armstrong number
# 3
# 7
# t= 73 s= 370
# not a armstrong number
# 4
# 7
# t= 74 s= 407
# not a armstrong number
# 5
# 7
# t= 75 s= 468
# not a armstrong number
# 6
# 7
# t= 76 s= 559
# not a armstrong number
# 7
# 7
# t= 77 s= 686
# not a armstrong number
# 8
# 7
# t= 78 s= 855
# not a armstrong number
# 9
# 7
# t= 79 s= 1072
# not a armstrong number
# 0
# 8
# t= 80 s= 512
# not a armstrong number
# 1
# 8
# t= 81 s= 513
# not a armstrong number
# 2
# 8
# t= 82 s= 520
# not a armstrong number
# 3
# 8
# t= 83 s= 539
# not a armstrong number
# 4
# 8
# t= 84 s= 576
# not a armstrong number
# 5
# 8
# t= 85 s= 637
# not a armstrong number
# 6
# 8
# t= 86 s= 728
# not a armstrong number
# 7
# 8
# t= 87 s= 855
# not a armstrong number
# 8
# 8
# t= 88 s= 1024
# not a armstrong number
# 9
# 8
# t= 89 s= 1241
# not a armstrong number
# 0
# 9
# t= 90 s= 729
# not a armstrong number
# 1
# 9
# t= 91 s= 730
# not a armstrong number
# 2
# 9
# t= 92 s= 737
# not a armstrong number
# 3
# 9
# t= 93 s= 756
# not a armstrong number
# 4
# 9
# t= 94 s= 793
# not a armstrong number
# 5
# 9
# t= 95 s= 854
# not a armstrong number
# 6
# 9
# t= 96 s= 945
# not a armstrong number
# 7
# 9
# t= 97 s= 1072
# not a armstrong number
# 8
# 9
# t= 98 s= 1241
# not a armstrong number
# 9
# 9
# t= 99 s= 1458
# not a armstrong number
# 0
# 0
# 1
# t= 100 s= 1
# not a armstrong number
# 1
# 0
# 1
# t= 101 s= 2
# not a armstrong number
# 2
# 0
# 1
# t= 102 s= 9
# not a armstrong number
# 3
# 0
# 1
# t= 103 s= 28
# not a armstrong number
# 4
# 0
# 1
# t= 104 s= 65
# not a armstrong number
# 5
# 0
# 1
# t= 105 s= 126
# not a armstrong number
# 6
# 0
# 1
# t= 106 s= 217
# not a armstrong number
# 7
# 0
# 1
# t= 107 s= 344
# not a armstrong number
# 8
# 0
# 1
# t= 108 s= 513
# not a armstrong number
# 9
# 0
# 1
# t= 109 s= 730
# not a armstrong number
# 0
# 1
# 1
# t= 110 s= 2
# not a armstrong number
# 1
# 1
# 1
# t= 111 s= 3
# not a armstrong number
# 2
# 1
# 1
# t= 112 s= 10
# not a armstrong number
# 3
# 1
# 1
# t= 113 s= 29
# not a armstrong number
# 4
# 1
# 1
# t= 114 s= 66
# not a armstrong number
# 5
# 1
# 1
# t= 115 s= 127
# not a armstrong number
# 6
# 1
# 1
# t= 116 s= 218
# not a armstrong number
# 7
# 1
# 1
# t= 117 s= 345
# not a armstrong number
# 8
# 1
# 1
# t= 118 s= 514
# not a armstrong number
# 9
# 1
# 1
# t= 119 s= 731
# not a armstrong number
# 0
# 2
# 1
# t= 120 s= 9
# not a armstrong number
# 1
# 2
# 1
# t= 121 s= 10
# not a armstrong number
# 2
# 2
# 1
# t= 122 s= 17
# not a armstrong number
# 3
# 2
# 1
# t= 123 s= 36
# not a armstrong number
# 4
# 2
# 1
# t= 124 s= 73
# not a armstrong number
# 5
# 2
# 1
# t= 125 s= 134
# not a armstrong number
# 6
# 2
# 1
# t= 126 s= 225
# not a armstrong number
# 7
# 2
# 1
# t= 127 s= 352
# not a armstrong number
# 8
# 2
# 1
# t= 128 s= 521
# not a armstrong number
# 9
# 2
# 1
# t= 129 s= 738
# not a armstrong number
# 0
# 3
# 1
# t= 130 s= 28
# not a armstrong number
# 1
# 3
# 1
# t= 131 s= 29
# not a armstrong number
# 2
# 3
# 1
# t= 132 s= 36
# not a armstrong number
# 3
# 3
# 1
# t= 133 s= 55
# not a armstrong number
# 4
# 3
# 1
# t= 134 s= 92
# not a armstrong number
# 5
# 3
# 1
# t= 135 s= 153
# not a armstrong number
# 6
# 3
# 1
# t= 136 s= 244
# not a armstrong number
# 7
# 3
# 1
# t= 137 s= 371
# not a armstrong number
# 8
# 3
# 1
# t= 138 s= 540
# not a armstrong number
# 9
# 3
# 1
# t= 139 s= 757
# not a armstrong number
# 0
# 4
# 1
# t= 140 s= 65
# not a armstrong number
# 1
# 4
# 1
# t= 141 s= 66
# not a armstrong number
# 2
# 4
# 1
# t= 142 s= 73
# not a armstrong number
# 3
# 4
# 1
# t= 143 s= 92
# not a armstrong number
# 4
# 4
# 1
# t= 144 s= 129
# not a armstrong number
# 5
# 4
# 1
# t= 145 s= 190
# not a armstrong number
# 6
# 4
# 1
# t= 146 s= 281
# not a armstrong number
# 7
# 4
# 1
# t= 147 s= 408
# not a armstrong number
# 8
# 4
# 1
# t= 148 s= 577
# not a armstrong number
# 9
# 4
# 1
# t= 149 s= 794
# not a armstrong number
# 0
# 5
# 1
# t= 150 s= 126
# not a armstrong number
# 1
# 5
# 1
# t= 151 s= 127
# not a armstrong number
# 2
# 5
# 1
# t= 152 s= 134
# not a armstrong number
# 3
# 5
# 1
# t= 153 s= 153
# 153 is a armstrong number
# 4
# 5
# 1
# t= 154 s= 190
# not a armstrong number
# 5
# 5
# 1
# t= 155 s= 251
# not a armstrong number
# 6
# 5
# 1
# t= 156 s= 342
# not a armstrong number
# 7
# 5
# 1
# t= 157 s= 469
# not a armstrong number
# 8
# 5
# 1
# t= 158 s= 638
# not a armstrong number
# 9
# 5
# 1
# t= 159 s= 855
# not a armstrong number
# 0
# 6
# 1
# t= 160 s= 217
# not a armstrong number
# 1
# 6
# 1
# t= 161 s= 218
# not a armstrong number
# 2
# 6
# 1
# t= 162 s= 225
# not a armstrong number
# 3
# 6
# 1
# t= 163 s= 244
# not a armstrong number
# 4
# 6
# 1
# t= 164 s= 281
# not a armstrong number
# 5
# 6
# 1
# t= 165 s= 342
# not a armstrong number
# 6
# 6
# 1
# t= 166 s= 433
# not a armstrong number
# 7
# 6
# 1
# t= 167 s= 560
# not a armstrong number
# 8
# 6
# 1
# t= 168 s= 729
# not a armstrong number
# 9
# 6
# 1
# t= 169 s= 946
# not a armstrong number
# 0
# 7
# 1
# t= 170 s= 344
# not a armstrong number
# 1
# 7
# 1
# t= 171 s= 345
# not a armstrong number
# 2
# 7
# 1
# t= 172 s= 352
# not a armstrong number
# 3
# 7
# 1
# t= 173 s= 371
# not a armstrong number
# 4
# 7
# 1
# t= 174 s= 408
# not a armstrong number
# 5
# 7
# 1
# t= 175 s= 469
# not a armstrong number
# 6
# 7
# 1
# t= 176 s= 560
# not a armstrong number
# 7
# 7
# 1
# t= 177 s= 687
# not a armstrong number
# 8
# 7
# 1
# t= 178 s= 856
# not a armstrong number
# 9
# 7
# 1
# t= 179 s= 1073
# not a armstrong number
# 0
# 8
# 1
# t= 180 s= 513
# not a armstrong number
# 1
# 8
# 1
# t= 181 s= 514
# not a armstrong number
# 2
# 8
# 1
# t= 182 s= 521
# not a armstrong number
# 3
# 8
# 1
# t= 183 s= 540
# not a armstrong number
# 4
# 8
# 1
# t= 184 s= 577
# not a armstrong number
# 5
# 8
# 1
# t= 185 s= 638
# not a armstrong number
# 6
# 8
# 1
# t= 186 s= 729
# not a armstrong number
# 7
# 8
# 1
# t= 187 s= 856
# not a armstrong number
# 8
# 8
# 1
# t= 188 s= 1025
# not a armstrong number
# 9
# 8
# 1
# t= 189 s= 1242
# not a armstrong number
# 0
# 9
# 1
# t= 190 s= 730
# not a armstrong number
# 1
# 9
# 1
# t= 191 s= 731
# not a armstrong number
# 2
# 9
# 1
# t= 192 s= 738
# not a armstrong number
# 3
# 9
# 1
# t= 193 s= 757
# not a armstrong number
# 4
# 9
# 1
# t= 194 s= 794
# not a armstrong number
# 5
# 9
# 1
# t= 195 s= 855
# not a armstrong number
# 6
# 9
# 1
# t= 196 s= 946
# not a armstrong number
# 7
# 9
# 1
# t= 197 s= 1073
# not a armstrong number
# 8
# 9
# 1
# t= 198 s= 1242
# not a armstrong number
# 9
# 9
# 1
# t= 199 s= 1459
# not a armstrong number
# 0
# 0
# 2
# t= 200 s= 8
# not a armstrong number
# 1
# 0
# 2
# t= 201 s= 9
# not a armstrong number
# 2
# 0
# 2
# t= 202 s= 16
# not a armstrong number
# 3
# 0
# 2
# t= 203 s= 35
# not a armstrong number
# 4
# 0
# 2
# t= 204 s= 72
# not a armstrong number
# 5
# 0
# 2
# t= 205 s= 133
# not a armstrong number
# 6
# 0
# 2
# t= 206 s= 224
# not a armstrong number
# 7
# 0
# 2
# t= 207 s= 351
# not a armstrong number
# 8
# 0
# 2
# t= 208 s= 520
# not a armstrong number
# 9
# 0
# 2
# t= 209 s= 737
# not a armstrong number
# 0
# 1
# 2
# t= 210 s= 9
# not a armstrong number
# 1
# 1
# 2
# t= 211 s= 10
# not a armstrong number
# 2
# 1
# 2
# t= 212 s= 17
# not a armstrong number
# 3
# 1
# 2
# t= 213 s= 36
# not a armstrong number
# 4
# 1
# 2
# t= 214 s= 73
# not a armstrong number
# 5
# 1
# 2
# t= 215 s= 134
# not a armstrong number
# 6
# 1
# 2
# t= 216 s= 225
# not a armstrong number
# 7
# 1
# 2
# t= 217 s= 352
# not a armstrong number
# 8
# 1
# 2
# t= 218 s= 521
# not a armstrong number
# 9
# 1
# 2
# t= 219 s= 738
# not a armstrong number
# 0
# 2
# 2
# t= 220 s= 16
# not a armstrong number
# 1
# 2
# 2
# t= 221 s= 17
# not a armstrong number
# 2
# 2
# 2
# t= 222 s= 24
# not a armstrong number
# 3
# 2
# 2
# t= 223 s= 43
# not a armstrong number
# 4
# 2
# 2
# t= 224 s= 80
# not a armstrong number
# 5
# 2
# 2
# t= 225 s= 141
# not a armstrong number
# 6
# 2
# 2
# t= 226 s= 232
# not a armstrong number
# 7
# 2
# 2
# t= 227 s= 359
# not a armstrong number
# 8
# 2
# 2
# t= 228 s= 528
# not a armstrong number
# 9
# 2
# 2
# t= 229 s= 745
# not a armstrong number
# 0
# 3
# 2
# t= 230 s= 35
# not a armstrong number
# 1
# 3
# 2
# t= 231 s= 36
# not a armstrong number
# 2
# 3
# 2
# t= 232 s= 43
# not a armstrong number
# 3
# 3
# 2
# t= 233 s= 62
# not a armstrong number
# 4
# 3
# 2
# t= 234 s= 99
# not a armstrong number
# 5
# 3
# 2
# t= 235 s= 160
# not a armstrong number
# 6
# 3
# 2
# t= 236 s= 251
# not a armstrong number
# 7
# 3
# 2
# t= 237 s= 378
# not a armstrong number
# 8
# 3
# 2
# t= 238 s= 547
# not a armstrong number
# 9
# 3
# 2
# t= 239 s= 764
# not a armstrong number
# 0
# 4
# 2
# t= 240 s= 72
# not a armstrong number
# 1
# 4
# 2
# t= 241 s= 73
# not a armstrong number
# 2
# 4
# 2
# t= 242 s= 80
# not a armstrong number
# 3
# 4
# 2
# t= 243 s= 99
# not a armstrong number
# 4
# 4
# 2
# t= 244 s= 136
# not a armstrong number
# 5
# 4
# 2
# t= 245 s= 197
# not a armstrong number
# 6
# 4
# 2
# t= 246 s= 288
# not a armstrong number
# 7
# 4
# 2
# t= 247 s= 415
# not a armstrong number
# 8
# 4
# 2
# t= 248 s= 584
# not a armstrong number
# 9
# 4
# 2
# t= 249 s= 801
# not a armstrong number
# 0
# 5
# 2
# t= 250 s= 133
# not a armstrong number
# 1
# 5
# 2
# t= 251 s= 134
# not a armstrong number
# 2
# 5
# 2
# t= 252 s= 141
# not a armstrong number
# 3
# 5
# 2
# t= 253 s= 160
# not a armstrong number
# 4
# 5
# 2
# t= 254 s= 197
# not a armstrong number
# 5
# 5
# 2
# t= 255 s= 258
# not a armstrong number
# 6
# 5
# 2
# t= 256 s= 349
# not a armstrong number
# 7
# 5
# 2
# t= 257 s= 476
# not a armstrong number
# 8
# 5
# 2
# t= 258 s= 645
# not a armstrong number
# 9
# 5
# 2
# t= 259 s= 862
# not a armstrong number
# 0
# 6
# 2
# t= 260 s= 224
# not a armstrong number
# 1
# 6
# 2
# t= 261 s= 225
# not a armstrong number
# 2
# 6
# 2
# t= 262 s= 232
# not a armstrong number
# 3
# 6
# 2
# t= 263 s= 251
# not a armstrong number
# 4
# 6
# 2
# t= 264 s= 288
# not a armstrong number
# 5
# 6
# 2
# t= 265 s= 349
# not a armstrong number
# 6
# 6
# 2
# t= 266 s= 440
# not a armstrong number
# 7
# 6
# 2
# t= 267 s= 567
# not a armstrong number
# 8
# 6
# 2
# t= 268 s= 736
# not a armstrong number
# 9
# 6
# 2
# t= 269 s= 953
# not a armstrong number
# 0
# 7
# 2
# t= 270 s= 351
# not a armstrong number
# 1
# 7
# 2
# t= 271 s= 352
# not a armstrong number
# 2
# 7
# 2
# t= 272 s= 359
# not a armstrong number
# 3
# 7
# 2
# t= 273 s= 378
# not a armstrong number
# 4
# 7
# 2
# t= 274 s= 415
# not a armstrong number
# 5
# 7
# 2
# t= 275 s= 476
# not a armstrong number
# 6
# 7
# 2
# t= 276 s= 567
# not a armstrong number
# 7
# 7
# 2
# t= 277 s= 694
# not a armstrong number
# 8
# 7
# 2
# t= 278 s= 863
# not a armstrong number
# 9
# 7
# 2
# t= 279 s= 1080
# not a armstrong number
# 0
# 8
# 2
# t= 280 s= 520
# not a armstrong number
# 1
# 8
# 2
# t= 281 s= 521
# not a armstrong number
# 2
# 8
# 2
# t= 282 s= 528
# not a armstrong number
# 3
# 8
# 2
# t= 283 s= 547
# not a armstrong number
# 4
# 8
# 2
# t= 284 s= 584
# not a armstrong number
# 5
# 8
# 2
# t= 285 s= 645
# not a armstrong number
# 6
# 8
# 2
# t= 286 s= 736
# not a armstrong number
# 7
# 8
# 2
# t= 287 s= 863
# not a armstrong number
# 8
# 8
# 2
# t= 288 s= 1032
# not a armstrong number
# 9
# 8
# 2
# t= 289 s= 1249
# not a armstrong number
# 0
# 9
# 2
# t= 290 s= 737
# not a armstrong number
# 1
# 9
# 2
# t= 291 s= 738
# not a armstrong number
# 2
# 9
# 2
# t= 292 s= 745
# not a armstrong number
# 3
# 9
# 2
# t= 293 s= 764
# not a armstrong number
# 4
# 9
# 2
# t= 294 s= 801
# not a armstrong number
# 5
# 9
# 2
# t= 295 s= 862
# not a armstrong number
# 6
# 9
# 2
# t= 296 s= 953
# not a armstrong number
# 7
# 9
# 2
# t= 297 s= 1080
# not a armstrong number
# 8
# 9
# 2
# t= 298 s= 1249
# not a armstrong number
# 9
# 9
# 2
# t= 299 s= 1466
# not a armstrong number
# 0
# 0
# 3
# t= 300 s= 27
# not a armstrong number
# 1
# 0
# 3
# t= 301 s= 28
# not a armstrong number
# 2
# 0
# 3
# t= 302 s= 35
# not a armstrong number
# 3
# 0
# 3
# t= 303 s= 54
# not a armstrong number
# 4
# 0
# 3
# t= 304 s= 91
# not a armstrong number
# 5
# 0
# 3
# t= 305 s= 152
# not a armstrong number
# 6
# 0
# 3
# t= 306 s= 243
# not a armstrong number
# 7
# 0
# 3
# t= 307 s= 370
# not a armstrong number
# 8
# 0
# 3
# t= 308 s= 539
# not a armstrong number
# 9
# 0
# 3
# t= 309 s= 756
# not a armstrong number
# 0
# 1
# 3
# t= 310 s= 28
# not a armstrong number
# 1
# 1
# 3
# t= 311 s= 29
# not a armstrong number
# 2
# 1
# 3
# t= 312 s= 36
# not a armstrong number
# 3
# 1
# 3
# t= 313 s= 55
# not a armstrong number
# 4
# 1
# 3
# t= 314 s= 92
# not a armstrong number
# 5
# 1
# 3
# t= 315 s= 153
# not a armstrong number
# 6
# 1
# 3
# t= 316 s= 244
# not a armstrong number
# 7
# 1
# 3
# t= 317 s= 371
# not a armstrong number
# 8
# 1
# 3
# t= 318 s= 540
# not a armstrong number
# 9
# 1
# 3
# t= 319 s= 757
# not a armstrong number
# 0
# 2
# 3
# t= 320 s= 35
# not a armstrong number
# 1
# 2
# 3
# t= 321 s= 36
# not a armstrong number
# 2
# 2
# 3
# t= 322 s= 43
# not a armstrong number
# 3
# 2
# 3
# t= 323 s= 62
# not a armstrong number
# 4
# 2
# 3
# t= 324 s= 99
# not a armstrong number
# 5
# 2
# 3
# t= 325 s= 160
# not a armstrong number
# 6
# 2
# 3
# t= 326 s= 251
# not a armstrong number
# 7
# 2
# 3
# t= 327 s= 378
# not a armstrong number
# 8
# 2
# 3
# t= 328 s= 547
# not a armstrong number
# 9
# 2
# 3
# t= 329 s= 764
# not a armstrong number
# 0
# 3
# 3
# t= 330 s= 54
# not a armstrong number
# 1
# 3
# 3
# t= 331 s= 55
# not a armstrong number
# 2
# 3
# 3
# t= 332 s= 62
# not a armstrong number
# 3
# 3
# 3
# t= 333 s= 81
# not a armstrong number
# 4
# 3
# 3
# t= 334 s= 118
# not a armstrong number
# 5
# 3
# 3
# t= 335 s= 179
# not a armstrong number
# 6
# 3
# 3
# t= 336 s= 270
# not a armstrong number
# 7
# 3
# 3
# t= 337 s= 397
# not a armstrong number
# 8
# 3
# 3
# t= 338 s= 566
# not a armstrong number
# 9
# 3
# 3
# t= 339 s= 783
# not a armstrong number
# 0
# 4
# 3
# t= 340 s= 91
# not a armstrong number
# 1
# 4
# 3
# t= 341 s= 92
# not a armstrong number
# 2
# 4
# 3
# t= 342 s= 99
# not a armstrong number
# 3
# 4
# 3
# t= 343 s= 118
# not a armstrong number
# 4
# 4
# 3
# t= 344 s= 155
# not a armstrong number
# 5
# 4
# 3
# t= 345 s= 216
# not a armstrong number
# 6
# 4
# 3
# t= 346 s= 307
# not a armstrong number
# 7
# 4
# 3
# t= 347 s= 434
# not a armstrong number
# 8
# 4
# 3
# t= 348 s= 603
# not a armstrong number
# 9
# 4
# 3
# t= 349 s= 820
# not a armstrong number
# 0
# 5
# 3
# t= 350 s= 152
# not a armstrong number
# 1
# 5
# 3
# t= 351 s= 153
# not a armstrong number
# 2
# 5
# 3
# t= 352 s= 160
# not a armstrong number
# 3
# 5
# 3
# t= 353 s= 179
# not a armstrong number
# 4
# 5
# 3
# t= 354 s= 216
# not a armstrong number
# 5
# 5
# 3
# t= 355 s= 277
# not a armstrong number
# 6
# 5
# 3
# t= 356 s= 368
# not a armstrong number
# 7
# 5
# 3
# t= 357 s= 495
# not a armstrong number
# 8
# 5
# 3
# t= 358 s= 664
# not a armstrong number
# 9
# 5
# 3
# t= 359 s= 881
# not a armstrong number
# 0
# 6
# 3
# t= 360 s= 243
# not a armstrong number
# 1
# 6
# 3
# t= 361 s= 244
# not a armstrong number
# 2
# 6
# 3
# t= 362 s= 251
# not a armstrong number
# 3
# 6
# 3
# t= 363 s= 270
# not a armstrong number
# 4
# 6
# 3
# t= 364 s= 307
# not a armstrong number
# 5
# 6
# 3
# t= 365 s= 368
# not a armstrong number
# 6
# 6
# 3
# t= 366 s= 459
# not a armstrong number
# 7
# 6
# 3
# t= 367 s= 586
# not a armstrong number
# 8
# 6
# 3
# t= 368 s= 755
# not a armstrong number
# 9
# 6
# 3
# t= 369 s= 972
# not a armstrong number
# 0
# 7
# 3
# t= 370 s= 370
# 370 is a armstrong number
# 1
# 7
# 3
# t= 371 s= 371
# 371 is a armstrong number
# 2
# 7
# 3
# t= 372 s= 378
# not a armstrong number
# 3
# 7
# 3
# t= 373 s= 397
# not a armstrong number
# 4
# 7
# 3
# t= 374 s= 434
# not a armstrong number
# 5
# 7
# 3
# t= 375 s= 495
# not a armstrong number
# 6
# 7
# 3
# t= 376 s= 586
# not a armstrong number
# 7
# 7
# 3
# t= 377 s= 713
# not a armstrong number
# 8
# 7
# 3
# t= 378 s= 882
# not a armstrong number
# 9
# 7
# 3
# t= 379 s= 1099
# not a armstrong number
# 0
# 8
# 3
# t= 380 s= 539
# not a armstrong number
# 1
# 8
# 3
# t= 381 s= 540
# not a armstrong number
# 2
# 8
# 3
# t= 382 s= 547
# not a armstrong number
# 3
# 8
# 3
# t= 383 s= 566
# not a armstrong number
# 4
# 8
# 3
# t= 384 s= 603
# not a armstrong number
# 5
# 8
# 3
# t= 385 s= 664
# not a armstrong number
# 6
# 8
# 3
# t= 386 s= 755
# not a armstrong number
# 7
# 8
# 3
# t= 387 s= 882
# not a armstrong number
# 8
# 8
# 3
# t= 388 s= 1051
# not a armstrong number
# 9
# 8
# 3
# t= 389 s= 1268
# not a armstrong number
# 0
# 9
# 3
# t= 390 s= 756
# not a armstrong number
# 1
# 9
# 3
# t= 391 s= 757
# not a armstrong number
# 2
# 9
# 3
# t= 392 s= 764
# not a armstrong number
# 3
# 9
# 3
# t= 393 s= 783
# not a armstrong number
# 4
# 9
# 3
# t= 394 s= 820
# not a armstrong number
# 5
# 9
# 3
# t= 395 s= 881
# not a armstrong number
# 6
# 9
# 3
# t= 396 s= 972
# not a armstrong number
# 7
# 9
# 3
# t= 397 s= 1099
# not a armstrong number
# 8
# 9
# 3
# t= 398 s= 1268
# not a armstrong number
# 9
# 9
# 3
# t= 399 s= 1485
# not a armstrong number
# 0
# 0
# 4
# t= 400 s= 64
# not a armstrong number
# 1
# 0
# 4
# t= 401 s= 65
# not a armstrong number
# 2
# 0
# 4
# t= 402 s= 72
# not a armstrong number
# 3
# 0
# 4
# t= 403 s= 91
# not a armstrong number
# 4
# 0
# 4
# t= 404 s= 128
# not a armstrong number
# 5
# 0
# 4
# t= 405 s= 189
# not a armstrong number
# 6
# 0
# 4
# t= 406 s= 280
# not a armstrong number
# 7
# 0
# 4
# t= 407 s= 407
# 407 is a armstrong number
# 8
# 0
# 4
# t= 408 s= 576
# not a armstrong number
# 9
# 0
# 4
# t= 409 s= 793
# not a armstrong number
# 0
# 1
# 4
# t= 410 s= 65
# not a armstrong number
# 1
# 1
# 4
# t= 411 s= 66
# not a armstrong number
# 2
# 1
# 4
# t= 412 s= 73
# not a armstrong number
# 3
# 1
# 4
# t= 413 s= 92
# not a armstrong number
# 4
# 1
# 4
# t= 414 s= 129
# not a armstrong number
# 5
# 1
# 4
# t= 415 s= 190
# not a armstrong number
# 6
# 1
# 4
# t= 416 s= 281
# not a armstrong number
# 7
# 1
# 4
# t= 417 s= 408
# not a armstrong number
# 8
# 1
# 4
# t= 418 s= 577
# not a armstrong number
# 9
# 1
# 4
# t= 419 s= 794
# not a armstrong number
# 0
# 2
# 4
# t= 420 s= 72
# not a armstrong number
# 1
# 2
# 4
# t= 421 s= 73
# not a armstrong number
# 2
# 2
# 4
# t= 422 s= 80
# not a armstrong number
# 3
# 2
# 4
# t= 423 s= 99
# not a armstrong number
# 4
# 2
# 4
# t= 424 s= 136
# not a armstrong number
# 5
# 2
# 4
# t= 425 s= 197
# not a armstrong number
# 6
# 2
# 4
# t= 426 s= 288
# not a armstrong number
# 7
# 2
# 4
# t= 427 s= 415
# not a armstrong number
# 8
# 2
# 4
# t= 428 s= 584
# not a armstrong number
# 9
# 2
# 4
# t= 429 s= 801
# not a armstrong number
# 0
# 3
# 4
# t= 430 s= 91
# not a armstrong number
# 1
# 3
# 4
# t= 431 s= 92
# not a armstrong number
# 2
# 3
# 4
# t= 432 s= 99
# not a armstrong number
# 3
# 3
# 4
# t= 433 s= 118
# not a armstrong number
# 4
# 3
# 4
# t= 434 s= 155
# not a armstrong number
# 5
# 3
# 4
# t= 435 s= 216
# not a armstrong number
# 6
# 3
# 4
# t= 436 s= 307
# not a armstrong number
# 7
# 3
# 4
# t= 437 s= 434
# not a armstrong number
# 8
# 3
# 4
# t= 438 s= 603
# not a armstrong number
# 9
# 3
# 4
# t= 439 s= 820
# not a armstrong number
# 0
# 4
# 4
# t= 440 s= 128
# not a armstrong number
# 1
# 4
# 4
# t= 441 s= 129
# not a armstrong number
# 2
# 4
# 4
# t= 442 s= 136
# not a armstrong number
# 3
# 4
# 4
# t= 443 s= 155
# not a armstrong number
# 4
# 4
# 4
# t= 444 s= 192
# not a armstrong number
# 5
# 4
# 4
# t= 445 s= 253
# not a armstrong number
# 6
# 4
# 4
# t= 446 s= 344
# not a armstrong number
# 7
# 4
# 4
# t= 447 s= 471
# not a armstrong number
# 8
# 4
# 4
# t= 448 s= 640
# not a armstrong number
# 9
# 4
# 4
# t= 449 s= 857
# not a armstrong number
# 0
# 5
# 4
# t= 450 s= 189
# not a armstrong number
# 1
# 5
# 4
# t= 451 s= 190
# not a armstrong number
# 2
# 5
# 4
# t= 452 s= 197
# not a armstrong number
# 3
# 5
# 4
# t= 453 s= 216
# not a armstrong number
# 4
# 5
# 4
# t= 454 s= 253
# not a armstrong number
# 5
# 5
# 4
# t= 455 s= 314
# not a armstrong number
# 6
# 5
# 4
# t= 456 s= 405
# not a armstrong number
# 7
# 5
# 4
# t= 457 s= 532
# not a armstrong number
# 8
# 5
# 4
# t= 458 s= 701
# not a armstrong number
# 9
# 5
# 4
# t= 459 s= 918
# not a armstrong number
# 0
# 6
# 4
# t= 460 s= 280
# not a armstrong number
# 1
# 6
# 4
# t= 461 s= 281
# not a armstrong number
# 2
# 6
# 4
# t= 462 s= 288
# not a armstrong number
# 3
# 6
# 4
# t= 463 s= 307
# not a armstrong number
# 4
# 6
# 4
# t= 464 s= 344
# not a armstrong number
# 5
# 6
# 4
# t= 465 s= 405
# not a armstrong number
# 6
# 6
# 4
# t= 466 s= 496
# not a armstrong number
# 7
# 6
# 4
# t= 467 s= 623
# not a armstrong number
# 8
# 6
# 4
# t= 468 s= 792
# not a armstrong number
# 9
# 6
# 4
# t= 469 s= 1009
# not a armstrong number
# 0
# 7
# 4
# t= 470 s= 407
# not a armstrong number
# 1
# 7
# 4
# t= 471 s= 408
# not a armstrong number
# 2
# 7
# 4
# t= 472 s= 415
# not a armstrong number
# 3
# 7
# 4
# t= 473 s= 434
# not a armstrong number
# 4
# 7
# 4
# t= 474 s= 471
# not a armstrong number
# 5
# 7
# 4
# t= 475 s= 532
# not a armstrong number
# 6
# 7
# 4
# t= 476 s= 623
# not a armstrong number
# 7
# 7
# 4
# t= 477 s= 750
# not a armstrong number
# 8
# 7
# 4
# t= 478 s= 919
# not a armstrong number
# 9
# 7
# 4
# t= 479 s= 1136
# not a armstrong number
# 0
# 8
# 4
# t= 480 s= 576
# not a armstrong number
# 1
# 8
# 4
# t= 481 s= 577
# not a armstrong number
# 2
# 8
# 4
# t= 482 s= 584
# not a armstrong number
# 3
# 8
# 4
# t= 483 s= 603
# not a armstrong number
# 4
# 8
# 4
# t= 484 s= 640
# not a armstrong number
# 5
# 8
# 4
# t= 485 s= 701
# not a armstrong number
# 6
# 8
# 4
# t= 486 s= 792
# not a armstrong number
# 7
# 8
# 4
# t= 487 s= 919
# not a armstrong number
# 8
# 8
# 4
# t= 488 s= 1088
# not a armstrong number
# 9
# 8
# 4
# t= 489 s= 1305
# not a armstrong number
# 0
# 9
# 4
# t= 490 s= 793
# not a armstrong number
# 1
# 9
# 4
# t= 491 s= 794
# not a armstrong number
# 2
# 9
# 4
# t= 492 s= 801
# not a armstrong number
# 3
# 9
# 4
# t= 493 s= 820
# not a armstrong number
# 4
# 9
# 4
# t= 494 s= 857
# not a armstrong number
# 5
# 9
# 4
# t= 495 s= 918
# not a armstrong number
# 6
# 9
# 4
# t= 496 s= 1009
# not a armstrong number
# 7
# 9
# 4
# t= 497 s= 1136
# not a armstrong number
# 8
# 9
# 4
# t= 498 s= 1305
# not a armstrong number
# 9
# 9
# 4
# t= 499 s= 1522
# not a armstrong number
# 0
# 0
# 5
# t= 500 s= 125
# not a armstrong number
# 1
# 0
# 5
# t= 501 s= 126
# not a armstrong number
# 2
# 0
# 5
# t= 502 s= 133
# not a armstrong number
# 3
# 0
# 5
# t= 503 s= 152
# not a armstrong number
# 4
# 0
# 5
# t= 504 s= 189
# not a armstrong number
# 5
# 0
# 5
# t= 505 s= 250
# not a armstrong number
# 6
# 0
# 5
# t= 506 s= 341
# not a armstrong number
# 7
# 0
# 5
# t= 507 s= 468
# not a armstrong number
# 8
# 0
# 5
# t= 508 s= 637
# not a armstrong number
# 9
# 0
# 5
# t= 509 s= 854
# not a armstrong number
# 0
# 1
# 5
# t= 510 s= 126
# not a armstrong number
# 1
# 1
# 5
# t= 511 s= 127
# not a armstrong number
# 2
# 1
# 5
# t= 512 s= 134
# not a armstrong number
# 3
# 1
# 5
# t= 513 s= 153
# not a armstrong number
# 4
# 1
# 5
# t= 514 s= 190
# not a armstrong number
# 5
# 1
# 5
# t= 515 s= 251
# not a armstrong number
# 6
# 1
# 5
# t= 516 s= 342
# not a armstrong number
# 7
# 1
# 5
# t= 517 s= 469
# not a armstrong number
# 8
# 1
# 5
# t= 518 s= 638
# not a armstrong number
# 9
# 1
# 5
# t= 519 s= 855
# not a armstrong number
# 0
# 2
# 5
# t= 520 s= 133
# not a armstrong number
# 1
# 2
# 5
# t= 521 s= 134
# not a armstrong number
# 2
# 2
# 5
# t= 522 s= 141
# not a armstrong number
# 3
# 2
# 5
# t= 523 s= 160
# not a armstrong number
# 4
# 2
# 5
# t= 524 s= 197
# not a armstrong number
# 5
# 2
# 5
# t= 525 s= 258
# not a armstrong number
# 6
# 2
# 5
# t= 526 s= 349
# not a armstrong number
# 7
# 2
# 5
# t= 527 s= 476
# not a armstrong number
# 8
# 2
# 5
# t= 528 s= 645
# not a armstrong number
# 9
# 2
# 5
# t= 529 s= 862
# not a armstrong number
# 0
# 3
# 5
# t= 530 s= 152
# not a armstrong number
# 1
# 3
# 5
# t= 531 s= 153
# not a armstrong number
# 2
# 3
# 5
# t= 532 s= 160
# not a armstrong number
# 3
# 3
# 5
# t= 533 s= 179
# not a armstrong number
# 4
# 3
# 5
# t= 534 s= 216
# not a armstrong number
# 5
# 3
# 5
# t= 535 s= 277
# not a armstrong number
# 6
# 3
# 5
# t= 536 s= 368
# not a armstrong number
# 7
# 3
# 5
# t= 537 s= 495
# not a armstrong number
# 8
# 3
# 5
# t= 538 s= 664
# not a armstrong number
# 9
# 3
# 5
# t= 539 s= 881
# not a armstrong number
# 0
# 4
# 5
# t= 540 s= 189
# not a armstrong number
# 1
# 4
# 5
# t= 541 s= 190
# not a armstrong number
# 2
# 4
# 5
# t= 542 s= 197
# not a armstrong number
# 3
# 4
# 5
# t= 543 s= 216
# not a armstrong number
# 4
# 4
# 5
# t= 544 s= 253
# not a armstrong number
# 5
# 4
# 5
# t= 545 s= 314
# not a armstrong number
# 6
# 4
# 5
# t= 546 s= 405
# not a armstrong number
# 7
# 4
# 5
# t= 547 s= 532
# not a armstrong number
# 8
# 4
# 5
# t= 548 s= 701
# not a armstrong number
# 9
# 4
# 5
# t= 549 s= 918
# not a armstrong number
# 0
# 5
# 5
# t= 550 s= 250
# not a armstrong number
# 1
# 5
# 5
# t= 551 s= 251
# not a armstrong number
# 2
# 5
# 5
# t= 552 s= 258
# not a armstrong number
# 3
# 5
# 5
# t= 553 s= 277
# not a armstrong number
# 4
# 5
# 5
# t= 554 s= 314
# not a armstrong number
# 5
# 5
# 5
# t= 555 s= 375
# not a armstrong number
# 6
# 5
# 5
# t= 556 s= 466
# not a armstrong number
# 7
# 5
# 5
# t= 557 s= 593
# not a armstrong number
# 8
# 5
# 5
# t= 558 s= 762
# not a armstrong number
# 9
# 5
# 5
# t= 559 s= 979
# not a armstrong number
# 0
# 6
# 5
# t= 560 s= 341
# not a armstrong number
# 1
# 6
# 5
# t= 561 s= 342
# not a armstrong number
# 2
# 6
# 5
# t= 562 s= 349
# not a armstrong number
# 3
# 6
# 5
# t= 563 s= 368
# not a armstrong number
# 4
# 6
# 5
# t= 564 s= 405
# not a armstrong number
# 5
# 6
# 5
# t= 565 s= 466
# not a armstrong number
# 6
# 6
# 5
# t= 566 s= 557
# not a armstrong number
# 7
# 6
# 5
# t= 567 s= 684
# not a armstrong number
# 8
# 6
# 5
# t= 568 s= 853
# not a armstrong number
# 9
# 6
# 5
# t= 569 s= 1070
# not a armstrong number
# 0
# 7
# 5
# t= 570 s= 468
# not a armstrong number
# 1
# 7
# 5
# t= 571 s= 469
# not a armstrong number
# 2
# 7
# 5
# t= 572 s= 476
# not a armstrong number
# 3
# 7
# 5
# t= 573 s= 495
# not a armstrong number
# 4
# 7
# 5
# t= 574 s= 532
# not a armstrong number
# 5
# 7
# 5
# t= 575 s= 593
# not a armstrong number
# 6
# 7
# 5
# t= 576 s= 684
# not a armstrong number
# 7
# 7
# 5
# t= 577 s= 811
# not a armstrong number
# 8
# 7
# 5
# t= 578 s= 980
# not a armstrong number
# 9
# 7
# 5
# t= 579 s= 1197
# not a armstrong number
# 0
# 8
# 5
# t= 580 s= 637
# not a armstrong number
# 1
# 8
# 5
# t= 581 s= 638
# not a armstrong number
# 2
# 8
# 5
# t= 582 s= 645
# not a armstrong number
# 3
# 8
# 5
# t= 583 s= 664
# not a armstrong number
# 4
# 8
# 5
# t= 584 s= 701
# not a armstrong number
# 5
# 8
# 5
# t= 585 s= 762
# not a armstrong number
# 6
# 8
# 5
# t= 586 s= 853
# not a armstrong number
# 7
# 8
# 5
# t= 587 s= 980
# not a armstrong number
# 8
# 8
# 5
# t= 588 s= 1149
# not a armstrong number
# 9
# 8
# 5
# t= 589 s= 1366
# not a armstrong number
# 0
# 9
# 5
# t= 590 s= 854
# not a armstrong number
# 1
# 9
# 5
# t= 591 s= 855
# not a armstrong number
# 2
# 9
# 5
# t= 592 s= 862
# not a armstrong number
# 3
# 9
# 5
# t= 593 s= 881
# not a armstrong number
# 4
# 9
# 5
# t= 594 s= 918
# not a armstrong number
# 5
# 9
# 5
# t= 595 s= 979
# not a armstrong number
# 6
# 9
# 5
# t= 596 s= 1070
# not a armstrong number
# 7
# 9
# 5
# t= 597 s= 1197
# not a armstrong number
# 8
# 9
# 5
# t= 598 s= 1366
# not a armstrong number
# 9
# 9
# 5
# t= 599 s= 1583
# not a armstrong number
# 0
# 0
# 6
# t= 600 s= 216
# not a armstrong number
# 1
# 0
# 6
# t= 601 s= 217
# not a armstrong number
# 2
# 0
# 6
# t= 602 s= 224
# not a armstrong number
# 3
# 0
# 6
# t= 603 s= 243
# not a armstrong number
# 4
# 0
# 6
# t= 604 s= 280
# not a armstrong number
# 5
# 0
# 6
# t= 605 s= 341
# not a armstrong number
# 6
# 0
# 6
# t= 606 s= 432
# not a armstrong number
# 7
# 0
# 6
# t= 607 s= 559
# not a armstrong number
# 8
# 0
# 6
# t= 608 s= 728
# not a armstrong number
# 9
# 0
# 6
# t= 609 s= 945
# not a armstrong number
# 0
# 1
# 6
# t= 610 s= 217
# not a armstrong number
# 1
# 1
# 6
# t= 611 s= 218
# not a armstrong number
# 2
# 1
# 6
# t= 612 s= 225
# not a armstrong number
# 3
# 1
# 6
# t= 613 s= 244
# not a armstrong number
# 4
# 1
# 6
# t= 614 s= 281
# not a armstrong number
# 5
# 1
# 6
# t= 615 s= 342
# not a armstrong number
# 6
# 1
# 6
# t= 616 s= 433
# not a armstrong number
# 7
# 1
# 6
# t= 617 s= 560
# not a armstrong number
# 8
# 1
# 6
# t= 618 s= 729
# not a armstrong number
# 9
# 1
# 6
# t= 619 s= 946
# not a armstrong number
# 0
# 2
# 6
# t= 620 s= 224
# not a armstrong number
# 1
# 2
# 6
# t= 621 s= 225
# not a armstrong number
# 2
# 2
# 6
# t= 622 s= 232
# not a armstrong number
# 3
# 2
# 6
# t= 623 s= 251
# not a armstrong number
# 4
# 2
# 6
# t= 624 s= 288
# not a armstrong number
# 5
# 2
# 6
# t= 625 s= 349
# not a armstrong number
# 6
# 2
# 6
# t= 626 s= 440
# not a armstrong number
# 7
# 2
# 6
# t= 627 s= 567
# not a armstrong number
# 8
# 2
# 6
# t= 628 s= 736
# not a armstrong number
# 9
# 2
# 6
# t= 629 s= 953
# not a armstrong number
# 0
# 3
# 6
# t= 630 s= 243
# not a armstrong number
# 1
# 3
# 6
# t= 631 s= 244
# not a armstrong number
# 2
# 3
# 6
# t= 632 s= 251
# not a armstrong number
# 3
# 3
# 6
# t= 633 s= 270
# not a armstrong number
# 4
# 3
# 6
# t= 634 s= 307
# not a armstrong number
# 5
# 3
# 6
# t= 635 s= 368
# not a armstrong number
# 6
# 3
# 6
# t= 636 s= 459
# not a armstrong number
# 7
# 3
# 6
# t= 637 s= 586
# not a armstrong number
# 8
# 3
# 6
# t= 638 s= 755
# not a armstrong number
# 9
# 3
# 6
# t= 639 s= 972
# not a armstrong number
# 0
# 4
# 6
# t= 640 s= 280
# not a armstrong number
# 1
# 4
# 6
# t= 641 s= 281
# not a armstrong number
# 2
# 4
# 6
# t= 642 s= 288
# not a armstrong number
# 3
# 4
# 6
# t= 643 s= 307
# not a armstrong number
# 4
# 4
# 6
# t= 644 s= 344
# not a armstrong number
# 5
# 4
# 6
# t= 645 s= 405
# not a armstrong number
# 6
# 4
# 6
# t= 646 s= 496
# not a armstrong number
# 7
# 4
# 6
# t= 647 s= 623
# not a armstrong number
# 8
# 4
# 6
# t= 648 s= 792
# not a armstrong number
# 9
# 4
# 6
# t= 649 s= 1009
# not a armstrong number
# 0
# 5
# 6
# t= 650 s= 341
# not a armstrong number
# 1
# 5
# 6
# t= 651 s= 342
# not a armstrong number
# 2
# 5
# 6
# t= 652 s= 349
# not a armstrong number
# 3
# 5
# 6
# t= 653 s= 368
# not a armstrong number
# 4
# 5
# 6
# t= 654 s= 405
# not a armstrong number
# 5
# 5
# 6
# t= 655 s= 466
# not a armstrong number
# 6
# 5
# 6
# t= 656 s= 557
# not a armstrong number
# 7
# 5
# 6
# t= 657 s= 684
# not a armstrong number
# 8
# 5
# 6
# t= 658 s= 853
# not a armstrong number
# 9
# 5
# 6
# t= 659 s= 1070
# not a armstrong number
# 0
# 6
# 6
# t= 660 s= 432
# not a armstrong number
# 1
# 6
# 6
# t= 661 s= 433
# not a armstrong number
# 2
# 6
# 6
# t= 662 s= 440
# not a armstrong number
# 3
# 6
# 6
# t= 663 s= 459
# not a armstrong number
# 4
# 6
# 6
# t= 664 s= 496
# not a armstrong number
# 5
# 6
# 6
# t= 665 s= 557
# not a armstrong number
# 6
# 6
# 6
# t= 666 s= 648
# not a armstrong number
# 7
# 6
# 6
# t= 667 s= 775
# not a armstrong number
# 8
# 6
# 6
# t= 668 s= 944
# not a armstrong number
# 9
# 6
# 6
# t= 669 s= 1161
# not a armstrong number
# 0
# 7
# 6
# t= 670 s= 559
# not a armstrong number
# 1
# 7
# 6
# t= 671 s= 560
# not a armstrong number
# 2
# 7
# 6
# t= 672 s= 567
# not a armstrong number
# 3
# 7
# 6
# t= 673 s= 586
# not a armstrong number
# 4
# 7
# 6
# t= 674 s= 623
# not a armstrong number
# 5
# 7
# 6
# t= 675 s= 684
# not a armstrong number
# 6
# 7
# 6
# t= 676 s= 775
# not a armstrong number
# 7
# 7
# 6
# t= 677 s= 902
# not a armstrong number
# 8
# 7
# 6
# t= 678 s= 1071
# not a armstrong number
# 9
# 7
# 6
# t= 679 s= 1288
# not a armstrong number
# 0
# 8
# 6
# t= 680 s= 728
# not a armstrong number
# 1
# 8
# 6
# t= 681 s= 729
# not a armstrong number
# 2
# 8
# 6
# t= 682 s= 736
# not a armstrong number
# 3
# 8
# 6
# t= 683 s= 755
# not a armstrong number
# 4
# 8
# 6
# t= 684 s= 792
# not a armstrong number
# 5
# 8
# 6
# t= 685 s= 853
# not a armstrong number
# 6
# 8
# 6
# t= 686 s= 944
# not a armstrong number
# 7
# 8
# 6
# t= 687 s= 1071
# not a armstrong number
# 8
# 8
# 6
# t= 688 s= 1240
# not a armstrong number
# 9
# 8
# 6
# t= 689 s= 1457
# not a armstrong number
# 0
# 9
# 6
# t= 690 s= 945
# not a armstrong number
# 1
# 9
# 6
# t= 691 s= 946
# not a armstrong number
# 2
# 9
# 6
# t= 692 s= 953
# not a armstrong number
# 3
# 9
# 6
# t= 693 s= 972
# not a armstrong number
# 4
# 9
# 6
# t= 694 s= 1009
# not a armstrong number
# 5
# 9
# 6
# t= 695 s= 1070
# not a armstrong number
# 6
# 9
# 6
# t= 696 s= 1161
# not a armstrong number
# 7
# 9
# 6
# t= 697 s= 1288
# not a armstrong number
# 8
# 9
# 6
# t= 698 s= 1457
# not a armstrong number
# 9
# 9
# 6
# t= 699 s= 1674
# not a armstrong number
# 0
# 0
# 7
# t= 700 s= 343
# not a armstrong number
# 1
# 0
# 7
# t= 701 s= 344
# not a armstrong number
# 2
# 0
# 7
# t= 702 s= 351
# not a armstrong number
# 3
# 0
# 7
# t= 703 s= 370
# not a armstrong number
# 4
# 0
# 7
# t= 704 s= 407
# not a armstrong number
# 5
# 0
# 7
# t= 705 s= 468
# not a armstrong number
# 6
# 0
# 7
# t= 706 s= 559
# not a armstrong number
# 7
# 0
# 7
# t= 707 s= 686
# not a armstrong number
# 8
# 0
# 7
# t= 708 s= 855
# not a armstrong number
# 9
# 0
# 7
# t= 709 s= 1072
# not a armstrong number
# 0
# 1
# 7
# t= 710 s= 344
# not a armstrong number
# 1
# 1
# 7
# t= 711 s= 345
# not a armstrong number
# 2
# 1
# 7
# t= 712 s= 352
# not a armstrong number
# 3
# 1
# 7
# t= 713 s= 371
# not a armstrong number
# 4
# 1
# 7
# t= 714 s= 408
# not a armstrong number
# 5
# 1
# 7
# t= 715 s= 469
# not a armstrong number
# 6
# 1
# 7
# t= 716 s= 560
# not a armstrong number
# 7
# 1
# 7
# t= 717 s= 687
# not a armstrong number
# 8
# 1
# 7
# t= 718 s= 856
# not a armstrong number
# 9
# 1
# 7
# t= 719 s= 1073
# not a armstrong number
# 0
# 2
# 7
# t= 720 s= 351
# not a armstrong number
# 1
# 2
# 7
# t= 721 s= 352
# not a armstrong number
# 2
# 2
# 7
# t= 722 s= 359
# not a armstrong number
# 3
# 2
# 7
# t= 723 s= 378
# not a armstrong number
# 4
# 2
# 7
# t= 724 s= 415
# not a armstrong number
# 5
# 2
# 7
# t= 725 s= 476
# not a armstrong number
# 6
# 2
# 7
# t= 726 s= 567
# not a armstrong number
# 7
# 2
# 7
# t= 727 s= 694
# not a armstrong number
# 8
# 2
# 7
# t= 728 s= 863
# not a armstrong number
# 9
# 2
# 7
# t= 729 s= 1080
# not a armstrong number
# 0
# 3
# 7
# t= 730 s= 370
# not a armstrong number
# 1
# 3
# 7
# t= 731 s= 371
# not a armstrong number
# 2
# 3
# 7
# t= 732 s= 378
# not a armstrong number
# 3
# 3
# 7
# t= 733 s= 397
# not a armstrong number
# 4
# 3
# 7
# t= 734 s= 434
# not a armstrong number
# 5
# 3
# 7
# t= 735 s= 495
# not a armstrong number
# 6
# 3
# 7
# t= 736 s= 586
# not a armstrong number
# 7
# 3
# 7
# t= 737 s= 713
# not a armstrong number
# 8
# 3
# 7
# t= 738 s= 882
# not a armstrong number
# 9
# 3
# 7
# t= 739 s= 1099
# not a armstrong number
# 0
# 4
# 7
# t= 740 s= 407
# not a armstrong number
# 1
# 4
# 7
# t= 741 s= 408
# not a armstrong number
# 2
# 4
# 7
# t= 742 s= 415
# not a armstrong number
# 3
# 4
# 7
# t= 743 s= 434
# not a armstrong number
# 4
# 4
# 7
# t= 744 s= 471
# not a armstrong number
# 5
# 4
# 7
# t= 745 s= 532
# not a armstrong number
# 6
# 4
# 7
# t= 746 s= 623
# not a armstrong number
# 7
# 4
# 7
# t= 747 s= 750
# not a armstrong number
# 8
# 4
# 7
# t= 748 s= 919
# not a armstrong number
# 9
# 4
# 7
# t= 749 s= 1136
# not a armstrong number
# 0
# 5
# 7
# t= 750 s= 468
# not a armstrong number
# 1
# 5
# 7
# t= 751 s= 469
# not a armstrong number
# 2
# 5
# 7
# t= 752 s= 476
# not a armstrong number
# 3
# 5
# 7
# t= 753 s= 495
# not a armstrong number
# 4
# 5
# 7
# t= 754 s= 532
# not a armstrong number
# 5
# 5
# 7
# t= 755 s= 593
# not a armstrong number
# 6
# 5
# 7
# t= 756 s= 684
# not a armstrong number
# 7
# 5
# 7
# t= 757 s= 811
# not a armstrong number
# 8
# 5
# 7
# t= 758 s= 980
# not a armstrong number
# 9
# 5
# 7
# t= 759 s= 1197
# not a armstrong number
# 0
# 6
# 7
# t= 760 s= 559
# not a armstrong number
# 1
# 6
# 7
# t= 761 s= 560
# not a armstrong number
# 2
# 6
# 7
# t= 762 s= 567
# not a armstrong number
# 3
# 6
# 7
# t= 763 s= 586
# not a armstrong number
# 4
# 6
# 7
# t= 764 s= 623
# not a armstrong number
# 5
# 6
# 7
# t= 765 s= 684
# not a armstrong number
# 6
# 6
# 7
# t= 766 s= 775
# not a armstrong number
# 7
# 6
# 7
# t= 767 s= 902
# not a armstrong number
# 8
# 6
# 7
# t= 768 s= 1071
# not a armstrong number
# 9
# 6
# 7
# t= 769 s= 1288
# not a armstrong number
# 0
# 7
# 7
# t= 770 s= 686
# not a armstrong number
# 1
# 7
# 7
# t= 771 s= 687
# not a armstrong number
# 2
# 7
# 7
# t= 772 s= 694
# not a armstrong number
# 3
# 7
# 7
# t= 773 s= 713
# not a armstrong number
# 4
# 7
# 7
# t= 774 s= 750
# not a armstrong number
# 5
# 7
# 7
# t= 775 s= 811
# not a armstrong number
# 6
# 7
# 7
# t= 776 s= 902
# not a armstrong number
# 7
# 7
# 7
# t= 777 s= 1029
# not a armstrong number
# 8
# 7
# 7
# t= 778 s= 1198
# not a armstrong number
# 9
# 7
# 7
# t= 779 s= 1415
# not a armstrong number
# 0
# 8
# 7
# t= 780 s= 855
# not a armstrong number
# 1
# 8
# 7
# t= 781 s= 856
# not a armstrong number
# 2
# 8
# 7
# t= 782 s= 863
# not a armstrong number
# 3
# 8
# 7
# t= 783 s= 882
# not a armstrong number
# 4
# 8
# 7
# t= 784 s= 919
# not a armstrong number
# 5
# 8
# 7
# t= 785 s= 980
# not a armstrong number
# 6
# 8
# 7
# t= 786 s= 1071
# not a armstrong number
# 7
# 8
# 7
# t= 787 s= 1198
# not a armstrong number
# 8
# 8
# 7
# t= 788 s= 1367
# not a armstrong number
# 9
# 8
# 7
# t= 789 s= 1584
# not a armstrong number
# 0
# 9
# 7
# t= 790 s= 1072
# not a armstrong number
# 1
# 9
# 7
# t= 791 s= 1073
# not a armstrong number
# 2
# 9
# 7
# t= 792 s= 1080
# not a armstrong number
# 3
# 9
# 7
# t= 793 s= 1099
# not a armstrong number
# 4
# 9
# 7
# t= 794 s= 1136
# not a armstrong number
# 5
# 9
# 7
# t= 795 s= 1197
# not a armstrong number
# 6
# 9
# 7
# t= 796 s= 1288
# not a armstrong number
# 7
# 9
# 7
# t= 797 s= 1415
# not a armstrong number
# 8
# 9
# 7
# t= 798 s= 1584
# not a armstrong number
# 9
# 9
# 7
# t= 799 s= 1801
# not a armstrong number
# 0
# 0
# 8
# t= 800 s= 512
# not a armstrong number
# 1
# 0
# 8
# t= 801 s= 513
# not a armstrong number
# 2
# 0
# 8
# t= 802 s= 520
# not a armstrong number
# 3
# 0
# 8
# t= 803 s= 539
# not a armstrong number
# 4
# 0
# 8
# t= 804 s= 576
# not a armstrong number
# 5
# 0
# 8
# t= 805 s= 637
# not a armstrong number
# 6
# 0
# 8
# t= 806 s= 728
# not a armstrong number
# 7
# 0
# 8
# t= 807 s= 855
# not a armstrong number
# 8
# 0
# 8
# t= 808 s= 1024
# not a armstrong number
# 9
# 0
# 8
# t= 809 s= 1241
# not a armstrong number
# 0
# 1
# 8
# t= 810 s= 513
# not a armstrong number
# 1
# 1
# 8
# t= 811 s= 514
# not a armstrong number
# 2
# 1
# 8
# t= 812 s= 521
# not a armstrong number
# 3
# 1
# 8
# t= 813 s= 540
# not a armstrong number
# 4
# 1
# 8
# t= 814 s= 577
# not a armstrong number
# 5
# 1
# 8
# t= 815 s= 638
# not a armstrong number
# 6
# 1
# 8
# t= 816 s= 729
# not a armstrong number
# 7
# 1
# 8
# t= 817 s= 856
# not a armstrong number
# 8
# 1
# 8
# t= 818 s= 1025
# not a armstrong number
# 9
# 1
# 8
# t= 819 s= 1242
# not a armstrong number
# 0
# 2
# 8
# t= 820 s= 520
# not a armstrong number
# 1
# 2
# 8
# t= 821 s= 521
# not a armstrong number
# 2
# 2
# 8
# t= 822 s= 528
# not a armstrong number
# 3
# 2
# 8
# t= 823 s= 547
# not a armstrong number
# 4
# 2
# 8
# t= 824 s= 584
# not a armstrong number
# 5
# 2
# 8
# t= 825 s= 645
# not a armstrong number
# 6
# 2
# 8
# t= 826 s= 736
# not a armstrong number
# 7
# 2
# 8
# t= 827 s= 863
# not a armstrong number
# 8
# 2
# 8
# t= 828 s= 1032
# not a armstrong number
# 9
# 2
# 8
# t= 829 s= 1249
# not a armstrong number
# 0
# 3
# 8
# t= 830 s= 539
# not a armstrong number
# 1
# 3
# 8
# t= 831 s= 540
# not a armstrong number
# 2
# 3
# 8
# t= 832 s= 547
# not a armstrong number
# 3
# 3
# 8
# t= 833 s= 566
# not a armstrong number
# 4
# 3
# 8
# t= 834 s= 603
# not a armstrong number
# 5
# 3
# 8
# t= 835 s= 664
# not a armstrong number
# 6
# 3
# 8
# t= 836 s= 755
# not a armstrong number
# 7
# 3
# 8
# t= 837 s= 882
# not a armstrong number
# 8
# 3
# 8
# t= 838 s= 1051
# not a armstrong number
# 9
# 3
# 8
# t= 839 s= 1268
# not a armstrong number
# 0
# 4
# 8
# t= 840 s= 576
# not a armstrong number
# 1
# 4
# 8
# t= 841 s= 577
# not a armstrong number
# 2
# 4
# 8
# t= 842 s= 584
# not a armstrong number
# 3
# 4
# 8
# t= 843 s= 603
# not a armstrong number
# 4
# 4
# 8
# t= 844 s= 640
# not a armstrong number
# 5
# 4
# 8
# t= 845 s= 701
# not a armstrong number
# 6
# 4
# 8
# t= 846 s= 792
# not a armstrong number
# 7
# 4
# 8
# t= 847 s= 919
# not a armstrong number
# 8
# 4
# 8
# t= 848 s= 1088
# not a armstrong number
# 9
# 4
# 8
# t= 849 s= 1305
# not a armstrong number
# 0
# 5
# 8
# t= 850 s= 637
# not a armstrong number
# 1
# 5
# 8
# t= 851 s= 638
# not a armstrong number
# 2
# 5
# 8
# t= 852 s= 645
# not a armstrong number
# 3
# 5
# 8
# t= 853 s= 664
# not a armstrong number
# 4
# 5
# 8
# t= 854 s= 701
# not a armstrong number
# 5
# 5
# 8
# t= 855 s= 762
# not a armstrong number
# 6
# 5
# 8
# t= 856 s= 853
# not a armstrong number
# 7
# 5
# 8
# t= 857 s= 980
# not a armstrong number
# 8
# 5
# 8
# t= 858 s= 1149
# not a armstrong number
# 9
# 5
# 8
# t= 859 s= 1366
# not a armstrong number
# 0
# 6
# 8
# t= 860 s= 728
# not a armstrong number
# 1
# 6
# 8
# t= 861 s= 729
# not a armstrong number
# 2
# 6
# 8
# t= 862 s= 736
# not a armstrong number
# 3
# 6
# 8
# t= 863 s= 755
# not a armstrong number
# 4
# 6
# 8
# t= 864 s= 792
# not a armstrong number
# 5
# 6
# 8
# t= 865 s= 853
# not a armstrong number
# 6
# 6
# 8
# t= 866 s= 944
# not a armstrong number
# 7
# 6
# 8
# t= 867 s= 1071
# not a armstrong number
# 8
# 6
# 8
# t= 868 s= 1240
# not a armstrong number
# 9
# 6
# 8
# t= 869 s= 1457
# not a armstrong number
# 0
# 7
# 8
# t= 870 s= 855
# not a armstrong number
# 1
# 7
# 8
# t= 871 s= 856
# not a armstrong number
# 2
# 7
# 8
# t= 872 s= 863
# not a armstrong number
# 3
# 7
# 8
# t= 873 s= 882
# not a armstrong number
# 4
# 7
# 8
# t= 874 s= 919
# not a armstrong number
# 5
# 7
# 8
# t= 875 s= 980
# not a armstrong number
# 6
# 7
# 8
# t= 876 s= 1071
# not a armstrong number
# 7
# 7
# 8
# t= 877 s= 1198
# not a armstrong number
# 8
# 7
# 8
# t= 878 s= 1367
# not a armstrong number
# 9
# 7
# 8
# t= 879 s= 1584
# not a armstrong number
# 0
# 8
# 8
# t= 880 s= 1024
# not a armstrong number
# 1
# 8
# 8
# t= 881 s= 1025
# not a armstrong number
# 2
# 8
# 8
# t= 882 s= 1032
# not a armstrong number
# 3
# 8
# 8
# t= 883 s= 1051
# not a armstrong number
# 4
# 8
# 8
# t= 884 s= 1088
# not a armstrong number
# 5
# 8
# 8
# t= 885 s= 1149
# not a armstrong number
# 6
# 8
# 8
# t= 886 s= 1240
# not a armstrong number
# 7
# 8
# 8
# t= 887 s= 1367
# not a armstrong number
# 8
# 8
# 8
# t= 888 s= 1536
# not a armstrong number
# 9
# 8
# 8
# t= 889 s= 1753
# not a armstrong number
# 0
# 9
# 8
# t= 890 s= 1241
# not a armstrong number
# 1
# 9
# 8
# t= 891 s= 1242
# not a armstrong number
# 2
# 9
# 8
# t= 892 s= 1249
# not a armstrong number
# 3
# 9
# 8
# t= 893 s= 1268
# not a armstrong number
# 4
# 9
# 8
# t= 894 s= 1305
# not a armstrong number
# 5
# 9
# 8
# t= 895 s= 1366
# not a armstrong number
# 6
# 9
# 8
# t= 896 s= 1457
# not a armstrong number
# 7
# 9
# 8
# t= 897 s= 1584
# not a armstrong number
# 8
# 9
# 8
# t= 898 s= 1753
# not a armstrong number
# 9
# 9
# 8
# t= 899 s= 1970
# not a armstrong number
# 0
# 0
# 9
# t= 900 s= 729
# not a armstrong number
# 1
# 0
# 9
# t= 901 s= 730
# not a armstrong number
# 2
# 0
# 9
# t= 902 s= 737
# not a armstrong number
# 3
# 0
# 9
# t= 903 s= 756
# not a armstrong number
# 4
# 0
# 9
# t= 904 s= 793
# not a armstrong number
# 5
# 0
# 9
# t= 905 s= 854
# not a armstrong number
# 6
# 0
# 9
# t= 906 s= 945
# not a armstrong number
# 7
# 0
# 9
# t= 907 s= 1072
# not a armstrong number
# 8
# 0
# 9
# t= 908 s= 1241
# not a armstrong number
# 9
# 0
# 9
# t= 909 s= 1458
# not a armstrong number
# 0
# 1
# 9
# t= 910 s= 730
# not a armstrong number
# 1
# 1
# 9
# t= 911 s= 731
# not a armstrong number
# 2
# 1
# 9
# t= 912 s= 738
# not a armstrong number
# 3
# 1
# 9
# t= 913 s= 757
# not a armstrong number
# 4
# 1
# 9
# t= 914 s= 794
# not a armstrong number
# 5
# 1
# 9
# t= 915 s= 855
# not a armstrong number
# 6
# 1
# 9
# t= 916 s= 946
# not a armstrong number
# 7
# 1
# 9
# t= 917 s= 1073
# not a armstrong number
# 8
# 1
# 9
# t= 918 s= 1242
# not a armstrong number
# 9
# 1
# 9
# t= 919 s= 1459
# not a armstrong number
# 0
# 2
# 9
# t= 920 s= 737
# not a armstrong number
# 1
# 2
# 9
# t= 921 s= 738
# not a armstrong number
# 2
# 2
# 9
# t= 922 s= 745
# not a armstrong number
# 3
# 2
# 9
# t= 923 s= 764
# not a armstrong number
# 4
# 2
# 9
# t= 924 s= 801
# not a armstrong number
# 5
# 2
# 9
# t= 925 s= 862
# not a armstrong number
# 6
# 2
# 9
# t= 926 s= 953
# not a armstrong number
# 7
# 2
# 9
# t= 927 s= 1080
# not a armstrong number
# 8
# 2
# 9
# t= 928 s= 1249
# not a armstrong number
# 9
# 2
# 9
# t= 929 s= 1466
# not a armstrong number
# 0
# 3
# 9
# t= 930 s= 756
# not a armstrong number
# 1
# 3
# 9
# t= 931 s= 757
# not a armstrong number
# 2
# 3
# 9
# t= 932 s= 764
# not a armstrong number
# 3
# 3
# 9
# t= 933 s= 783
# not a armstrong number
# 4
# 3
# 9
# t= 934 s= 820
# not a armstrong number
# 5
# 3
# 9
# t= 935 s= 881
# not a armstrong number
# 6
# 3
# 9
# t= 936 s= 972
# not a armstrong number
# 7
# 3
# 9
# t= 937 s= 1099
# not a armstrong number
# 8
# 3
# 9
# t= 938 s= 1268
# not a armstrong number
# 9
# 3
# 9
# t= 939 s= 1485
# not a armstrong number
# 0
# 4
# 9
# t= 940 s= 793
# not a armstrong number
# 1
# 4
# 9
# t= 941 s= 794
# not a armstrong number
# 2
# 4
# 9
# t= 942 s= 801
# not a armstrong number
# 3
# 4
# 9
# t= 943 s= 820
# not a armstrong number
# 4
# 4
# 9
# t= 944 s= 857
# not a armstrong number
# 5
# 4
# 9
# t= 945 s= 918
# not a armstrong number
# 6
# 4
# 9
# t= 946 s= 1009
# not a armstrong number
# 7
# 4
# 9
# t= 947 s= 1136
# not a armstrong number
# 8
# 4
# 9
# t= 948 s= 1305
# not a armstrong number
# 9
# 4
# 9
# t= 949 s= 1522
# not a armstrong number
# 0
# 5
# 9
# t= 950 s= 854
# not a armstrong number
# 1
# 5
# 9
# t= 951 s= 855
# not a armstrong number
# 2
# 5
# 9
# t= 952 s= 862
# not a armstrong number
# 3
# 5
# 9
# t= 953 s= 881
# not a armstrong number
# 4
# 5
# 9
# t= 954 s= 918
# not a armstrong number
# 5
# 5
# 9
# t= 955 s= 979
# not a armstrong number
# 6
# 5
# 9
# t= 956 s= 1070
# not a armstrong number
# 7
# 5
# 9
# t= 957 s= 1197
# not a armstrong number
# 8
# 5
# 9
# t= 958 s= 1366
# not a armstrong number
# 9
# 5
# 9
# t= 959 s= 1583
# not a armstrong number
# 0
# 6
# 9
# t= 960 s= 945
# not a armstrong number
# 1
# 6
# 9
# t= 961 s= 946
# not a armstrong number
# 2
# 6
# 9
# t= 962 s= 953
# not a armstrong number
# 3
# 6
# 9
# t= 963 s= 972
# not a armstrong number
# 4
# 6
# 9
# t= 964 s= 1009
# not a armstrong number
# 5
# 6
# 9
# t= 965 s= 1070
# not a armstrong number
# 6
# 6
# 9
# t= 966 s= 1161
# not a armstrong number
# 7
# 6
# 9
# t= 967 s= 1288
# not a armstrong number
# 8
# 6
# 9
# t= 968 s= 1457
# not a armstrong number
# 9
# 6
# 9
# t= 969 s= 1674
# not a armstrong number
# 0
# 7
# 9
# t= 970 s= 1072
# not a armstrong number
# 1
# 7
# 9
# t= 971 s= 1073
# not a armstrong number
# 2
# 7
# 9
# t= 972 s= 1080
# not a armstrong number
# 3
# 7
# 9
# t= 973 s= 1099
# not a armstrong number
# 4
# 7
# 9
# t= 974 s= 1136
# not a armstrong number
# 5
# 7
# 9
# t= 975 s= 1197
# not a armstrong number
# 6
# 7
# 9
# t= 976 s= 1288
# not a armstrong number
# 7
# 7
# 9
# t= 977 s= 1415
# not a armstrong number
# 8
# 7
# 9
# t= 978 s= 1584
# not a armstrong number
# 9
# 7
# 9
# t= 979 s= 1801
# not a armstrong number
# 0
# 8
# 9
# t= 980 s= 1241
# not a armstrong number
# 1
# 8
# 9
# t= 981 s= 1242
# not a armstrong number
# 2
# 8
# 9
# t= 982 s= 1249
# not a armstrong number
# 3
# 8
# 9
# t= 983 s= 1268
# not a armstrong number
# 4
# 8
# 9
# t= 984 s= 1305
# not a armstrong number
# 5
# 8
# 9
# t= 985 s= 1366
# not a armstrong number
# 6
# 8
# 9
# t= 986 s= 1457
# not a armstrong number
# 7
# 8
# 9
# t= 987 s= 1584
# not a armstrong number
# 8
# 8
# 9
# t= 988 s= 1753
# not a armstrong number
# 9
# 8
# 9
# t= 989 s= 1970
# not a armstrong number
# 0
# 9
# 9
# t= 990 s= 1458
# not a armstrong number
# 1
# 9
# 9
# t= 991 s= 1459
# not a armstrong number
# 2
# 9
# 9
# t= 992 s= 1466
# not a armstrong number
# 3
# 9
# 9
# t= 993 s= 1485
# not a armstrong number
# 4
# 9
# 9
# t= 994 s= 1522
# not a armstrong number
# 5
# 9
# 9
# t= 995 s= 1583
# not a armstrong number
# 6
# 9
# 9
# t= 996 s= 1674
# not a armstrong number
# 7
# 9
# 9
# t= 997 s= 1801
# not a armstrong number
# 8
# 9
# 9
# t= 998 s= 1970
# not a armstrong number
# 9
# 9
# 9
# t= 999 s= 2187
# not a armstrong number

# %% [markdown]
# 10.	Write a Java program which iterates the integers from 1 to 100. For multiples of three print "Fizz" instead of the number and print "Buzz" for the multiples of five. When number is divided by both three and five, print "fizz buzz".

# %%
#10
for i in range(1,101):
    if(i%3==0 and i%5==0):
        print("fizz buzz")
    elif(i%3==0):
        print("Fizz")
    elif(i%5==0):
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# fizz buzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# fizz buzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# fizz buzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# fizz buzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# fizz buzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# fizz buzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# 11.	Spider Problem: A spider present at the bottom of the well of height H, needs to get out of it, using the slippery wall of the well. It decides to climb up the well; it goes up U meters and slips down D meters in one single step. So, in each step it covers (U-D) meters, and if the spider gets out of the well by covering U meters in the last step it doesn’t a slip back. For example, if the spider climbs up 5 meters and slips down by 3 meters in a single step, it covers (U - D) m in each step and 96 m in 48 steps, but in the 49th step it climbs up 5 m and reaches out of the well and it will not slip down and the step is counted as one step.
# Input: Each test case will contain 3 integers ’H’ height of the well, next ’U’ meters climbs up in each step, and the last ’D’ meters slips down in each step.
# Output:  The number of steps 'N' required to get out of the well.
# Example 1:
#  	Input:						Ouput
# 	200 50 1					    5
# 	Example 2:
#  	Input:						Output
# 	500 20 15					   98

# %%
#11
h=int(input('Enter height of the well: '))
u=int(input('distance-climbs up: '))
d=int(input('distance-slips down: '))
n=int((h-u)/(u-d))
n=n+2
print(n)
# Out:
# Enter height of the well: 200
# distance-climbs up: 10
# distance-slips down: 8
# 97
